# %% [markdown]
# ## Introduction to Linear Regression

# %% [markdown]
# This session covers the following topics:
#
# - Introduction to linear regression
# - Implementing a linear regression model using PyTorch tensors
# - Training a linear regression model using the gradient descent algorithm

# %% [markdown]
# Before we begin, we need to install the required libraries. The installation of PyTorch may differ based on your operating system / cloud environment. You can find detailed installation instructions here: https://pytorch.org .

# %%
# Uncomment and run the appropriate command for your operating system, if required

# Linux / Binder
# !pip install numpy torch==1.7.0+cpu torchvision==0.8.1+cpu 

# Windows
# !pip install numpy torch==1.7.0+cpu torchvision==0.8.1+cpu torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html

# MacOS
# !pip install numpy torch

# %% [markdown]
# ### Data
#
# *Linear regression* is one of the foundational algorithms in machine learning. Here we have crop yields for apples and oranges (called **target variables**) and corresponding average temperature, rainfall, and humidity (called **input variables or features**) in a region. Here's the training data:
#
# ![linear-regression-training-data](https://i.imgur.com/6Ujttb4.png)
#
# In a linear regression model, each target variable is estimated to be a weighted sum of the input variables, offset by some constant, known as a bias :
#
# ```
# yield_apple  = w11 * temp + w12 * rainfall + w13 * humidity + b1
# yield_orange = w21 * temp + w22 * rainfall + w23 * humidity + b2
# ```
#
# Visually, it means that the yield of apples is a linear or planar function of temperature, rainfall and humidity:
#
# ![linear-regression-graph](https://i.imgur.com/4DJ9f8X.png)

# %% [markdown]
# The *learning* part of linear regression is to figure out a set of weights `w11, w12,... w23, b1 & b2` using the training data, to make accurate predictions for new data. The _learned_ weights will be used to predict the yields for apples and oranges in a new region using the average temperature, rainfall, and humidity for that region.
#
# We'll _train_ our model by adjusting the weights slightly many times to make better predictions, using an optimization technique called *gradient descent*. Let's begin by importing Numpy and PyTorch.

# %%
import numpy as np
import torch

# %% [markdown]
# ## Training data
#
# We can represent the training data using two matrices: `inputs` and `targets`, each with one row per observation, and one column per variable.

# %%
# Input (temp, rainfall, humidity)
inputs = np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70]], dtype='float32')

# %%
# Targets (apples, oranges)
targets = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119]], dtype='float32')

# %% [markdown]
# We've separated the input and target variables because we'll operate on them separately. Also, we've created numpy arrays, because this is typically how you would work with training data: read some CSV files as numpy arrays, do some processing, and then convert them to PyTorch tensors.
#
# Let's convert the arrays to PyTorch tensors.

# %%
# Convert inputs and targets to tensors
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)
print(inputs)
print(targets)
# Out:
# tensor([[ 73.,  67.,  43.],
#         [ 91.,  88.,  64.],
#         [ 87., 134.,  58.],
#         [102.,  43.,  37.],
#         [ 69.,  96.,  70.]])
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# ## Linear regression model from scratch
#
# The weights and biases (`w11, w12,... w23, b1 & b2`) can also be represented as matrices, initialized as random values. The first row of `w` and the first element of `b` are used to predict the first target variable, i.e., yield of apples, and similarly, the second for oranges.

# %%
# Weights and biases
w = torch.randn(2, 3, requires_grad=True)
b = torch.randn(2, requires_grad=True)
print(w)
print(b)
# Out:
# tensor([[-1.5867,  0.8048, -1.6870],
#         [ 1.1467,  0.1319,  0.9204]], requires_grad=True)
# tensor([-1.4472, -1.6727], requires_grad=True)

# %% [markdown]
# `torch.randn` creates a tensor with the given shape, with elements picked randomly from a [normal distribution](https://en.wikipedia.org/wiki/Normal_distribution) with mean 0 and standard deviation 1.
#
# Our *model* is simply a function that performs a matrix multiplication of the `inputs` and the weights `w` (transposed) and adds the bias `b` (replicated for each observation).
#
# ![matrix-mult](https://i.imgur.com/WGXLFvA.png)
#
# We can define the model as follows:

# %%
def model(x):
    return x @ w.t() + b

# %% [markdown]
# `@` represents matrix multiplication in PyTorch, and the `.t` method returns the transpose of a tensor.
#
# The matrix obtained by passing the input data into the model is a set of predictions for the target variables.

# %%
# Generate predictions
preds = model(inputs)
print(preds)
# Out:
# tensor([[-135.8940,  130.4479],
#         [-182.9805,  173.1860],
#         [-129.4909,  169.1432],
#         [-191.1008,  155.0142],
#         [-151.7573,  154.5364]], grad_fn=<AddBackward0>)

# %% [markdown]
# Let's compare the predictions of our model with the actual targets.

# %%
# Compare with targets
print(targets)
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# You can see a big difference between our model's predictions and the actual targets because we've initialized our model with random weights and biases. Obviously, we can't expect a randomly initialized model to *just work*.

# %% [markdown]
# ## Loss function
#
# Before we improve our model, we need a way to evaluate how well our model is performing. We can compare the model's predictions with the actual targets using the following method:
#
# * Calculate the difference between the two matrices (`preds` and `targets`).
# * Square all elements of the difference matrix to remove negative values.
# * Calculate the average of the elements in the resulting matrix.
#
# The result is a single number, known as the **mean squared error** (MSE).

# %%
# MSE loss
def mse(t1, t2):
    diff = t1 - t2
    return torch.sum(diff * diff) / diff.numel()

# %% [markdown]
# `torch.sum` returns the sum of all the elements in a tensor. The `.numel` method of a tensor returns the number of elements in a tensor. Let's compute the mean squared error for the current predictions of our model.

# %%
# Compute loss
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(30393.1250, grad_fn=<DivBackward0>)

# %% [markdown]
# Here’s how we can interpret the result: *On average, each element in the prediction differs from the actual target by the square root of the loss*. And that’s pretty bad, considering the numbers we are trying to predict are themselves in the range 50–200. The result is called the *loss* because it indicates how bad the model is at predicting the target variables. It represents information loss in the model: the lower the loss, the better the model.

# %% [markdown]
# ## Compute gradients
#
# With PyTorch, we can automatically compute the gradient or derivative of the loss w.r.t. to the weights and biases because they have `requires_grad` set to `True`. We'll see how this is useful in just a moment.

# %% [markdown]
# Here is a link to a excellent tutorial on [gradient decent](https://hackernoon.com/dl03-gradient-descent-719aff91c7d6) with different visualisations.

# %%
# Compute gradients
loss.backward()

# %% [markdown]
# The gradients are stored in the `.grad` property of the respective tensors. Note that the derivative of the loss w.r.t. the weights matrix is itself a matrix with the same dimensions.

# %%
# Gradients for weights
print(w)
print(w.grad)
# Out:
# tensor([[-1.5867,  0.8048, -1.6870],
#         [ 1.1467,  0.1319,  0.9204]], requires_grad=True)
# tensor([[-19792.7480, -20601.0000, -13055.2812],
#         [  5723.1089,   4746.3350,   3233.9092]])

# %% [markdown]
# ## Adjust weights and biases to reduce the loss
#
# The loss is a [quadratic function](https://en.wikipedia.org/wiki/Quadratic_function) of our weights and biases, and our objective is to find the set of weights where the loss is the lowest. If we plot a graph of the loss w.r.t any individual weight or bias element, it will look like the figure shown below. An important insight from calculus is that the gradient indicates the rate of change of the loss, i.e., the loss function's [slope](https://en.wikipedia.org/wiki/Slope) w.r.t. the weights and biases.
#
# If a gradient element is **positive**:
#
# * **increasing** the weight element's value slightly will **increase** the loss
# * **decreasing** the weight element's value slightly will **decrease** the loss
#
# ![postive-gradient](https://i.imgur.com/WLzJ4xP.png)
#
# If a gradient element is **negative**:
#
# * **increasing** the weight element's value slightly will **decrease** the loss
# * **decreasing** the weight element's value slightly will **increase** the loss
#
# ![negative=gradient](https://i.imgur.com/dvG2fxU.png)
#
# The increase or decrease in the loss by changing a weight element is proportional to the gradient of the loss w.r.t. that element. This observation forms the basis of _the gradient descent_ optimization algorithm that we'll use to improve our model (by _descending_ along the _gradient_).
#
# We can subtract from each weight element a small quantity proportional to the derivative of the loss w.r.t. that element to reduce the loss slightly.

# %%
w
w.grad
# Out:
# tensor([[-19792.7480, -20601.0000, -13055.2812],
#         [  5723.1089,   4746.3350,   3233.9092]])

# %%
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5

# %%
w
# Out:
# tensor([[-1.3887,  1.0108, -1.5565],
#         [ 1.0894,  0.0844,  0.8881]], requires_grad=True)

# %% [markdown]
# We multiply the gradients with a very small number (`10^-5` in this case) to ensure that we don't modify the weights by a very large amount. We want to take a small step in the downhill direction of the gradient, not a giant leap. This number is called the **learning rate** of the algorithm.
#
# We use `torch.no_grad` to indicate to PyTorch that we shouldn't track, calculate, or modify gradients while updating the weights and biases.

# %%
# Let's verify that the loss is actually lower
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(30393.1250, grad_fn=<DivBackward0>)

# %% [markdown]
# Before we proceed, we reset the gradients to zero by invoking the `.zero_()` method. We need to do this because PyTorch accumulates gradients. Otherwise, the next time we invoke `.backward` on the loss, the new gradient values are added to the existing gradients, which may lead to unexpected results.

# %%
w.grad.zero_()
b.grad.zero_()
print(w.grad)
print(b.grad)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([0., 0.])

# %% [markdown]
# ## Train the model using gradient descent
#
# As seen above, we reduce the loss and improve our model using the gradient descent optimization algorithm. Thus, we can _train_ the model using the following steps:
#
# 1. Generate predictions
#
# 2. Calculate the loss
#
# 3. Compute gradients w.r.t the weights and biases
#
# 4. Adjust the weights by subtracting a small quantity proportional to the gradient
#
# 5. Reset the gradients to zero
#
# Let's implement the above step by step.

# %%
# Generate predictions
preds = model(inputs)
print(preds)
# Out:
# tensor([[-102.0266,  121.6988],
#         [-138.4825,  161.7309],
#         [ -77.0915,  155.9277],
#         [-157.2210,  145.9385],
#         [-109.1823,  143.7666]], grad_fn=<AddBackward0>)

# %%
# Calculate the loss
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(20810.5996, grad_fn=<DivBackward0>)

# %%
# Compute gradients
loss.backward()
print(w.grad)
print(b.grad)
# Out:
# tensor([[-16297.9844, -16850.9004, -10739.8525],
#         [  4823.1709,   3788.4792,   2640.8035]])
# tensor([-193.0008,   53.8125])

# %% [markdown]
# Let's update the weights and biases using the gradients computed above.

# %%
# Adjust weights & reset gradients
with torch.no_grad():
    w -= w.grad * 1e-5
    b -= b.grad * 1e-5
    w.grad.zero_()
    b.grad.zero_()

# %% [markdown]
# Let's take a look at the new weights and biases.

# %%
print(w)
print(b)
# Out:
# tensor([[-1.2258,  1.1793, -1.4491],
#         [ 1.0412,  0.0465,  0.8617]], requires_grad=True)
# tensor([-1.4429, -1.6739], requires_grad=True)

# %% [markdown]
# With the new weights and biases, the model should have a lower loss.

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(14349.4951, grad_fn=<DivBackward0>)

# %% [markdown]
# We have already achieved a significant reduction in the loss merely by adjusting the weights and biases slightly using gradient descent.

# %% [markdown]
# ## Train for multiple epochs
#
# To reduce the loss further, we can repeat the process of adjusting the weights and biases using the gradients multiple times. Each iteration is called an _epoch_. Let's train the model for 100 epochs.

# %%
# Train for 100 epochs
for i in range(500):
    preds = model(inputs)
    loss = mse(preds, targets)
    print(loss)
    loss.backward()
    with torch.no_grad():
        w -= w.grad * 1e-5
        b -= b.grad * 1e-5
        w.grad.zero_()
        b.grad.zero_()
# Out:
# tensor(14349.4951, grad_fn=<DivBackward0>)
# tensor(9991.9238, grad_fn=<DivBackward0>)
# tensor(7051.9351, grad_fn=<DivBackward0>)
# tensor(5067.2769, grad_fn=<DivBackward0>)
# tensor(3726.4453, grad_fn=<DivBackward0>)
# tensor(2819.5208, grad_fn=<DivBackward0>)
# tensor(2205.0415, grad_fn=<DivBackward0>)
# tensor(1787.6777, grad_fn=<DivBackward0>)
# tensor(1503.1877, grad_fn=<DivBackward0>)
# tensor(1308.2786, grad_fn=<DivBackward0>)
# tensor(1173.7766, grad_fn=<DivBackward0>)
# tensor(1080.0205, grad_fn=<DivBackward0>)
# tensor(1013.7609, grad_fn=<DivBackward0>)
# tensor(966.0687, grad_fn=<DivBackward0>)
# tensor(930.9261, grad_fn=<DivBackward0>)
# tensor(904.2772, grad_fn=<DivBackward0>)
# tensor(883.3888, grad_fn=<DivBackward0>)
# tensor(866.4178, grad_fn=<DivBackward0>)
# tensor(852.1227, grad_fn=<DivBackward0>)
# tensor(839.6656, grad_fn=<DivBackward0>)
# tensor(828.4818, grad_fn=<DivBackward0>)
# tensor(818.1901, grad_fn=<DivBackward0>)
# tensor(808.5334, grad_fn=<DivBackward0>)
# tensor(799.3383, grad_fn=<DivBackward0>)
# tensor(790.4865, grad_fn=<DivBackward0>)
# tensor(781.8990, grad_fn=<DivBackward0>)
# tensor(773.5218, grad_fn=<DivBackward0>)
# tensor(765.3174, grad_fn=<DivBackward0>)
# tensor(757.2612, grad_fn=<DivBackward0>)
# tensor(749.3353, grad_fn=<DivBackward0>)
# tensor(741.5285, grad_fn=<DivBackward0>)
# tensor(733.8314, grad_fn=<DivBackward0>)
# tensor(726.2380, grad_fn=<DivBackward0>)
# tensor(718.7445, grad_fn=<DivBackward0>)
# tensor(711.3466, grad_fn=<DivBackward0>)
# tensor(704.0418, grad_fn=<DivBackward0>)
# tensor(696.8283, grad_fn=<DivBackward0>)
# tensor(689.7040, grad_fn=<DivBackward0>)
# tensor(682.6676, grad_fn=<DivBackward0>)
# tensor(675.7177, grad_fn=<DivBackward0>)
# tensor(668.8528, grad_fn=<DivBackward0>)
# tensor(662.0715, grad_fn=<DivBackward0>)
# tensor(655.3730, grad_fn=<DivBackward0>)
# tensor(648.7563, grad_fn=<DivBackward0>)
# tensor(642.2202, grad_fn=<DivBackward0>)
# tensor(635.7635, grad_fn=<DivBackward0>)
# tensor(629.3854, grad_fn=<DivBackward0>)
# tensor(623.0848, grad_fn=<DivBackward0>)
# tensor(616.8604, grad_fn=<DivBackward0>)
# tensor(610.7119, grad_fn=<DivBackward0>)
# tensor(604.6379, grad_fn=<DivBackward0>)
# tensor(598.6373, grad_fn=<DivBackward0>)
# tensor(592.7098, grad_fn=<DivBackward0>)
# tensor(586.8541, grad_fn=<DivBackward0>)
# tensor(581.0692, grad_fn=<DivBackward0>)
# tensor(575.3542, grad_fn=<DivBackward0>)
# tensor(569.7086, grad_fn=<DivBackward0>)
# tensor(564.1312, grad_fn=<DivBackward0>)
# tensor(558.6211, grad_fn=<DivBackward0>)
# tensor(553.1776, grad_fn=<DivBackward0>)
# tensor(547.8000, grad_fn=<DivBackward0>)
# tensor(542.4871, grad_fn=<DivBackward0>)
# tensor(537.2386, grad_fn=<DivBackward0>)
# tensor(532.0531, grad_fn=<DivBackward0>)
# tensor(526.9303, grad_fn=<DivBackward0>)
# tensor(521.8693, grad_fn=<DivBackward0>)
# tensor(516.8690, grad_fn=<DivBackward0>)
# tensor(511.9290, grad_fn=<DivBackward0>)
# tensor(507.0486, grad_fn=<DivBackward0>)
# tensor(502.2265, grad_fn=<DivBackward0>)
# tensor(497.4626, grad_fn=<DivBackward0>)
# tensor(492.7558, grad_fn=<DivBackward0>)
# tensor(488.1057, grad_fn=<DivBackward0>)
# tensor(483.5111, grad_fn=<DivBackward0>)
# tensor(478.9721, grad_fn=<DivBackward0>)
# tensor(474.4872, grad_fn=<DivBackward0>)
# tensor(470.0558, grad_fn=<DivBackward0>)
# tensor(465.6777, grad_fn=<DivBackward0>)
# tensor(461.3521, grad_fn=<DivBackward0>)
# tensor(457.0779, grad_fn=<DivBackward0>)
# tensor(452.8551, grad_fn=<DivBackward0>)
# tensor(448.6827, grad_fn=<DivBackward0>)
# tensor(444.5599, grad_fn=<DivBackward0>)
# tensor(440.4864, grad_fn=<DivBackward0>)
# tensor(436.4616, grad_fn=<DivBackward0>)
# tensor(432.4847, grad_fn=<DivBackward0>)
# tensor(428.5552, grad_fn=<DivBackward0>)
# tensor(424.6724, grad_fn=<DivBackward0>)
# tensor(420.8358, grad_fn=<DivBackward0>)
# tensor(417.0448, grad_fn=<DivBackward0>)
# tensor(413.2988, grad_fn=<DivBackward0>)
# tensor(409.5974, grad_fn=<DivBackward0>)
# tensor(405.9399, grad_fn=<DivBackward0>)
# tensor(402.3257, grad_fn=<DivBackward0>)
# tensor(398.7543, grad_fn=<DivBackward0>)
# tensor(395.2253, grad_fn=<DivBackward0>)
# tensor(391.7380, grad_fn=<DivBackward0>)
# tensor(388.2921, grad_fn=<DivBackward0>)
# tensor(384.8867, grad_fn=<DivBackward0>)
# tensor(381.5216, grad_fn=<DivBackward0>)
# tensor(378.1962, grad_fn=<DivBackward0>)
# tensor(374.9101, grad_fn=<DivBackward0>)
# tensor(371.6628, grad_fn=<DivBackward0>)
# tensor(368.4536, grad_fn=<DivBackward0>)
# tensor(365.2818, grad_fn=<DivBackward0>)
# tensor(362.1478, grad_fn=<DivBackward0>)
# tensor(359.0506, grad_fn=<DivBackward0>)
# tensor(355.9897, grad_fn=<DivBackward0>)
# tensor(352.9644, grad_fn=<DivBackward0>)
# tensor(349.9752, grad_fn=<DivBackward0>)
# tensor(347.0205, grad_fn=<DivBackward0>)
# tensor(344.1005, grad_fn=<DivBackward0>)
# tensor(341.2149, grad_fn=<DivBackward0>)
# tensor(338.3626, grad_fn=<DivBackward0>)
# tensor(335.5440, grad_fn=<DivBackward0>)
# tensor(332.7581, grad_fn=<DivBackward0>)
# tensor(330.0047, grad_fn=<DivBackward0>)
# tensor(327.2834, grad_fn=<DivBackward0>)
# tensor(324.5938, grad_fn=<DivBackward0>)
# tensor(321.9355, grad_fn=<DivBackward0>)
# tensor(319.3080, grad_fn=<DivBackward0>)
# tensor(316.7109, grad_fn=<DivBackward0>)
# tensor(314.1442, grad_fn=<DivBackward0>)
# tensor(311.6071, grad_fn=<DivBackward0>)
# tensor(309.0994, grad_fn=<DivBackward0>)
# tensor(306.6208, grad_fn=<DivBackward0>)
# tensor(304.1708, grad_fn=<DivBackward0>)
# tensor(301.7491, grad_fn=<DivBackward0>)
# tensor(299.3553, grad_fn=<DivBackward0>)
# tensor(296.9891, grad_fn=<DivBackward0>)
# tensor(294.6501, grad_fn=<DivBackward0>)
# tensor(292.3381, grad_fn=<DivBackward0>)
# tensor(290.0525, grad_fn=<DivBackward0>)
# tensor(287.7935, grad_fn=<DivBackward0>)
# tensor(285.5600, grad_fn=<DivBackward0>)
# tensor(283.3526, grad_fn=<DivBackward0>)
# tensor(281.1701, grad_fn=<DivBackward0>)
# tensor(279.0128, grad_fn=<DivBackward0>)
# tensor(276.8799, grad_fn=<DivBackward0>)
# tensor(274.7715, grad_fn=<DivBackward0>)
# tensor(272.6871, grad_fn=<DivBackward0>)
# tensor(270.6264, grad_fn=<DivBackward0>)
# tensor(268.5893, grad_fn=<DivBackward0>)
# tensor(266.5753, grad_fn=<DivBackward0>)
# tensor(264.5840, grad_fn=<DivBackward0>)
# tensor(262.6155, grad_fn=<DivBackward0>)
# tensor(260.6691, grad_fn=<DivBackward0>)
# tensor(258.7451, grad_fn=<DivBackward0>)
# tensor(256.8425, grad_fn=<DivBackward0>)
# tensor(254.9615, grad_fn=<DivBackward0>)
# tensor(253.1018, grad_fn=<DivBackward0>)
# tensor(251.2629, grad_fn=<DivBackward0>)
# tensor(249.4449, grad_fn=<DivBackward0>)
# tensor(247.6473, grad_fn=<DivBackward0>)
# tensor(245.8698, grad_fn=<DivBackward0>)
# tensor(244.1122, grad_fn=<DivBackward0>)
# tensor(242.3744, grad_fn=<DivBackward0>)
# tensor(240.6560, grad_fn=<DivBackward0>)
# tensor(238.9568, grad_fn=<DivBackward0>)
# tensor(237.2766, grad_fn=<DivBackward0>)
# tensor(235.6151, grad_fn=<DivBackward0>)
# tensor(233.9722, grad_fn=<DivBackward0>)
# tensor(232.3474, grad_fn=<DivBackward0>)
# tensor(230.7407, grad_fn=<DivBackward0>)
# tensor(229.1518, grad_fn=<DivBackward0>)
# tensor(227.5807, grad_fn=<DivBackward0>)
# tensor(226.0269, grad_fn=<DivBackward0>)
# tensor(224.4902, grad_fn=<DivBackward0>)
# tensor(222.9704, grad_fn=<DivBackward0>)
# tensor(221.4674, grad_fn=<DivBackward0>)
# tensor(219.9809, grad_fn=<DivBackward0>)
# tensor(218.5109, grad_fn=<DivBackward0>)
# tensor(217.0569, grad_fn=<DivBackward0>)
# tensor(215.6189, grad_fn=<DivBackward0>)
# tensor(214.1967, grad_fn=<DivBackward0>)
# tensor(212.7899, grad_fn=<DivBackward0>)
# tensor(211.3985, grad_fn=<DivBackward0>)
# tensor(210.0222, grad_fn=<DivBackward0>)
# tensor(208.6609, grad_fn=<DivBackward0>)
# tensor(207.3145, grad_fn=<DivBackward0>)
# tensor(205.9826, grad_fn=<DivBackward0>)
# tensor(204.6653, grad_fn=<DivBackward0>)
# tensor(203.3621, grad_fn=<DivBackward0>)
# tensor(202.0730, grad_fn=<DivBackward0>)
# tensor(200.7978, grad_fn=<DivBackward0>)
# tensor(199.5363, grad_fn=<DivBackward0>)
# tensor(198.2883, grad_fn=<DivBackward0>)
# tensor(197.0539, grad_fn=<DivBackward0>)
# tensor(195.8324, grad_fn=<DivBackward0>)
# tensor(194.6244, grad_fn=<DivBackward0>)
# tensor(193.4291, grad_fn=<DivBackward0>)
# tensor(192.2466, grad_fn=<DivBackward0>)
# tensor(191.0765, grad_fn=<DivBackward0>)
# tensor(189.9190, grad_fn=<DivBackward0>)
# tensor(188.7740, grad_fn=<DivBackward0>)
# tensor(187.6408, grad_fn=<DivBackward0>)
# tensor(186.5197, grad_fn=<DivBackward0>)
# tensor(185.4104, grad_fn=<DivBackward0>)
# tensor(184.3128, grad_fn=<DivBackward0>)
# tensor(183.2267, grad_fn=<DivBackward0>)
# tensor(182.1522, grad_fn=<DivBackward0>)
# tensor(181.0887, grad_fn=<DivBackward0>)
# tensor(180.0367, grad_fn=<DivBackward0>)
# tensor(178.9952, grad_fn=<DivBackward0>)
# tensor(177.9650, grad_fn=<DivBackward0>)
# tensor(176.9452, grad_fn=<DivBackward0>)
# tensor(175.9363, grad_fn=<DivBackward0>)
# tensor(174.9379, grad_fn=<DivBackward0>)
# tensor(173.9495, grad_fn=<DivBackward0>)
# tensor(172.9714, grad_fn=<DivBackward0>)
# tensor(172.0035, grad_fn=<DivBackward0>)
# tensor(171.0456, grad_fn=<DivBackward0>)
# tensor(170.0975, grad_fn=<DivBackward0>)
# tensor(169.1592, grad_fn=<DivBackward0>)
# tensor(168.2303, grad_fn=<DivBackward0>)
# tensor(167.3110, grad_fn=<DivBackward0>)
# tensor(166.4010, grad_fn=<DivBackward0>)
# tensor(165.5005, grad_fn=<DivBackward0>)
# tensor(164.6088, grad_fn=<DivBackward0>)
# tensor(163.7262, grad_fn=<DivBackward0>)
# tensor(162.8527, grad_fn=<DivBackward0>)
# tensor(161.9879, grad_fn=<DivBackward0>)
# tensor(161.1320, grad_fn=<DivBackward0>)
# tensor(160.2843, grad_fn=<DivBackward0>)
# tensor(159.4455, grad_fn=<DivBackward0>)
# tensor(158.6148, grad_fn=<DivBackward0>)
# tensor(157.7925, grad_fn=<DivBackward0>)
# tensor(156.9785, grad_fn=<DivBackward0>)
# tensor(156.1725, grad_fn=<DivBackward0>)
# tensor(155.3746, grad_fn=<DivBackward0>)
# tensor(154.5844, grad_fn=<DivBackward0>)
# tensor(153.8022, grad_fn=<DivBackward0>)
# tensor(153.0276, grad_fn=<DivBackward0>)
# tensor(152.2605, grad_fn=<DivBackward0>)
# tensor(151.5011, grad_fn=<DivBackward0>)
# tensor(150.7490, grad_fn=<DivBackward0>)
# tensor(150.0044, grad_fn=<DivBackward0>)
# tensor(149.2669, grad_fn=<DivBackward0>)
# tensor(148.5367, grad_fn=<DivBackward0>)
# tensor(147.8134, grad_fn=<DivBackward0>)
# tensor(147.0973, grad_fn=<DivBackward0>)
# tensor(146.3881, grad_fn=<DivBackward0>)
# tensor(145.6856, grad_fn=<DivBackward0>)
# tensor(144.9897, grad_fn=<DivBackward0>)
# tensor(144.3008, grad_fn=<DivBackward0>)
# tensor(143.6183, grad_fn=<DivBackward0>)
# tensor(142.9424, grad_fn=<DivBackward0>)
# tensor(142.2729, grad_fn=<DivBackward0>)
# tensor(141.6095, grad_fn=<DivBackward0>)
# tensor(140.9527, grad_fn=<DivBackward0>)
# tensor(140.3018, grad_fn=<DivBackward0>)
# tensor(139.6573, grad_fn=<DivBackward0>)
# tensor(139.0188, grad_fn=<DivBackward0>)
# tensor(138.3861, grad_fn=<DivBackward0>)
# tensor(137.7595, grad_fn=<DivBackward0>)
# tensor(137.1387, grad_fn=<DivBackward0>)
# tensor(136.5236, grad_fn=<DivBackward0>)
# tensor(135.9142, grad_fn=<DivBackward0>)
# tensor(135.3103, grad_fn=<DivBackward0>)
# tensor(134.7122, grad_fn=<DivBackward0>)
# tensor(134.1195, grad_fn=<DivBackward0>)
# tensor(133.5321, grad_fn=<DivBackward0>)
# tensor(132.9503, grad_fn=<DivBackward0>)
# tensor(132.3736, grad_fn=<DivBackward0>)
# tensor(131.8022, grad_fn=<DivBackward0>)
# tensor(131.2360, grad_fn=<DivBackward0>)
# tensor(130.6749, grad_fn=<DivBackward0>)
# tensor(130.1188, grad_fn=<DivBackward0>)
# tensor(129.5678, grad_fn=<DivBackward0>)
# tensor(129.0217, grad_fn=<DivBackward0>)
# tensor(128.4805, grad_fn=<DivBackward0>)
# tensor(127.9440, grad_fn=<DivBackward0>)
# tensor(127.4122, grad_fn=<DivBackward0>)
# tensor(126.8854, grad_fn=<DivBackward0>)
# tensor(126.3629, grad_fn=<DivBackward0>)
# tensor(125.8452, grad_fn=<DivBackward0>)
# tensor(125.3321, grad_fn=<DivBackward0>)
# tensor(124.8233, grad_fn=<DivBackward0>)
# tensor(124.3190, grad_fn=<DivBackward0>)
# tensor(123.8192, grad_fn=<DivBackward0>)
# tensor(123.3236, grad_fn=<DivBackward0>)
# tensor(122.8323, grad_fn=<DivBackward0>)
# tensor(122.3453, grad_fn=<DivBackward0>)
# tensor(121.8623, grad_fn=<DivBackward0>)
# tensor(121.3836, grad_fn=<DivBackward0>)
# tensor(120.9089, grad_fn=<DivBackward0>)
# tensor(120.4382, grad_fn=<DivBackward0>)
# tensor(119.9715, grad_fn=<DivBackward0>)
# tensor(119.5089, grad_fn=<DivBackward0>)
# tensor(119.0500, grad_fn=<DivBackward0>)
# tensor(118.5949, grad_fn=<DivBackward0>)
# tensor(118.1437, grad_fn=<DivBackward0>)
# tensor(117.6963, grad_fn=<DivBackward0>)
# tensor(117.2525, grad_fn=<DivBackward0>)
# tensor(116.8125, grad_fn=<DivBackward0>)
# tensor(116.3761, grad_fn=<DivBackward0>)
# tensor(115.9433, grad_fn=<DivBackward0>)
# tensor(115.5139, grad_fn=<DivBackward0>)
# tensor(115.0880, grad_fn=<DivBackward0>)
# tensor(114.6657, grad_fn=<DivBackward0>)
# tensor(114.2469, grad_fn=<DivBackward0>)
# tensor(113.8313, grad_fn=<DivBackward0>)
# tensor(113.4190, grad_fn=<DivBackward0>)
# tensor(113.0102, grad_fn=<DivBackward0>)
# tensor(112.6044, grad_fn=<DivBackward0>)
# tensor(112.2021, grad_fn=<DivBackward0>)
# tensor(111.8029, grad_fn=<DivBackward0>)
# tensor(111.4068, grad_fn=<DivBackward0>)
# tensor(111.0140, grad_fn=<DivBackward0>)
# tensor(110.6240, grad_fn=<DivBackward0>)
# tensor(110.2372, grad_fn=<DivBackward0>)
# tensor(109.8534, grad_fn=<DivBackward0>)
# tensor(109.4726, grad_fn=<DivBackward0>)
# tensor(109.0948, grad_fn=<DivBackward0>)
# tensor(108.7197, grad_fn=<DivBackward0>)
# tensor(108.3476, grad_fn=<DivBackward0>)
# tensor(107.9783, grad_fn=<DivBackward0>)
# tensor(107.6119, grad_fn=<DivBackward0>)
# tensor(107.2483, grad_fn=<DivBackward0>)
# tensor(106.8873, grad_fn=<DivBackward0>)
# tensor(106.5291, grad_fn=<DivBackward0>)
# tensor(106.1735, grad_fn=<DivBackward0>)
# tensor(105.8206, grad_fn=<DivBackward0>)
# tensor(105.4704, grad_fn=<DivBackward0>)
# tensor(105.1227, grad_fn=<DivBackward0>)
# tensor(104.7777, grad_fn=<DivBackward0>)
# tensor(104.4352, grad_fn=<DivBackward0>)
# tensor(104.0952, grad_fn=<DivBackward0>)
# tensor(103.7575, grad_fn=<DivBackward0>)
# tensor(103.4224, grad_fn=<DivBackward0>)
# tensor(103.0897, grad_fn=<DivBackward0>)
# tensor(102.7594, grad_fn=<DivBackward0>)
# tensor(102.4314, grad_fn=<DivBackward0>)
# tensor(102.1060, grad_fn=<DivBackward0>)
# tensor(101.7827, grad_fn=<DivBackward0>)
# tensor(101.4617, grad_fn=<DivBackward0>)
# tensor(101.1430, grad_fn=<DivBackward0>)
# tensor(100.8265, grad_fn=<DivBackward0>)
# tensor(100.5123, grad_fn=<DivBackward0>)
# tensor(100.2002, grad_fn=<DivBackward0>)
# tensor(99.8903, grad_fn=<DivBackward0>)
# tensor(99.5826, grad_fn=<DivBackward0>)
# tensor(99.2769, grad_fn=<DivBackward0>)
# tensor(98.9733, grad_fn=<DivBackward0>)
# tensor(98.6718, grad_fn=<DivBackward0>)
# tensor(98.3725, grad_fn=<DivBackward0>)
# tensor(98.0750, grad_fn=<DivBackward0>)
# tensor(97.7796, grad_fn=<DivBackward0>)
# tensor(97.4862, grad_fn=<DivBackward0>)
# tensor(97.1949, grad_fn=<DivBackward0>)
# tensor(96.9052, grad_fn=<DivBackward0>)
# tensor(96.6177, grad_fn=<DivBackward0>)
# tensor(96.3319, grad_fn=<DivBackward0>)
# tensor(96.0482, grad_fn=<DivBackward0>)
# tensor(95.7662, grad_fn=<DivBackward0>)
# tensor(95.4861, grad_fn=<DivBackward0>)
# tensor(95.2077, grad_fn=<DivBackward0>)
# tensor(94.9312, grad_fn=<DivBackward0>)
# tensor(94.6564, grad_fn=<DivBackward0>)
# tensor(94.3834, grad_fn=<DivBackward0>)
# tensor(94.1121, grad_fn=<DivBackward0>)
# tensor(93.8426, grad_fn=<DivBackward0>)
# tensor(93.5748, grad_fn=<DivBackward0>)
# tensor(93.3086, grad_fn=<DivBackward0>)
# tensor(93.0441, grad_fn=<DivBackward0>)
# tensor(92.7813, grad_fn=<DivBackward0>)
# tensor(92.5200, grad_fn=<DivBackward0>)
# tensor(92.2604, grad_fn=<DivBackward0>)
# tensor(92.0024, grad_fn=<DivBackward0>)
# tensor(91.7461, grad_fn=<DivBackward0>)
# tensor(91.4911, grad_fn=<DivBackward0>)
# tensor(91.2378, grad_fn=<DivBackward0>)
# tensor(90.9861, grad_fn=<DivBackward0>)
# tensor(90.7359, grad_fn=<DivBackward0>)
# tensor(90.4869, grad_fn=<DivBackward0>)
# tensor(90.2397, grad_fn=<DivBackward0>)
# tensor(89.9938, grad_fn=<DivBackward0>)
# tensor(89.7494, grad_fn=<DivBackward0>)
# tensor(89.5065, grad_fn=<DivBackward0>)
# tensor(89.2648, grad_fn=<DivBackward0>)
# tensor(89.0247, grad_fn=<DivBackward0>)
# tensor(88.7860, grad_fn=<DivBackward0>)
# tensor(88.5485, grad_fn=<DivBackward0>)
# tensor(88.3126, grad_fn=<DivBackward0>)
# tensor(88.0778, grad_fn=<DivBackward0>)
# tensor(87.8445, grad_fn=<DivBackward0>)
# tensor(87.6125, grad_fn=<DivBackward0>)
# tensor(87.3819, grad_fn=<DivBackward0>)
# tensor(87.1523, grad_fn=<DivBackward0>)
# tensor(86.9241, grad_fn=<DivBackward0>)
# tensor(86.6972, grad_fn=<DivBackward0>)
# tensor(86.4716, grad_fn=<DivBackward0>)
# tensor(86.2472, grad_fn=<DivBackward0>)
# tensor(86.0239, grad_fn=<DivBackward0>)
# tensor(85.8020, grad_fn=<DivBackward0>)
# tensor(85.5813, grad_fn=<DivBackward0>)
# tensor(85.3617, grad_fn=<DivBackward0>)
# tensor(85.1433, grad_fn=<DivBackward0>)
# tensor(84.9261, grad_fn=<DivBackward0>)
# tensor(84.7100, grad_fn=<DivBackward0>)
# tensor(84.4951, grad_fn=<DivBackward0>)
# tensor(84.2812, grad_fn=<DivBackward0>)
# tensor(84.0685, grad_fn=<DivBackward0>)
# tensor(83.8570, grad_fn=<DivBackward0>)
# tensor(83.6465, grad_fn=<DivBackward0>)
# tensor(83.4371, grad_fn=<DivBackward0>)
# tensor(83.2288, grad_fn=<DivBackward0>)
# tensor(83.0215, grad_fn=<DivBackward0>)
# tensor(82.8152, grad_fn=<DivBackward0>)
# tensor(82.6101, grad_fn=<DivBackward0>)
# tensor(82.4060, grad_fn=<DivBackward0>)
# tensor(82.2030, grad_fn=<DivBackward0>)
# tensor(82.0009, grad_fn=<DivBackward0>)
# tensor(81.7998, grad_fn=<DivBackward0>)
# tensor(81.5996, grad_fn=<DivBackward0>)
# tensor(81.4005, grad_fn=<DivBackward0>)
# tensor(81.2024, grad_fn=<DivBackward0>)
# tensor(81.0052, grad_fn=<DivBackward0>)
# tensor(80.8090, grad_fn=<DivBackward0>)
# tensor(80.6138, grad_fn=<DivBackward0>)
# tensor(80.4195, grad_fn=<DivBackward0>)
# tensor(80.2261, grad_fn=<DivBackward0>)
# tensor(80.0336, grad_fn=<DivBackward0>)
# tensor(79.8420, grad_fn=<DivBackward0>)
# tensor(79.6513, grad_fn=<DivBackward0>)
# tensor(79.4616, grad_fn=<DivBackward0>)
# tensor(79.2726, grad_fn=<DivBackward0>)
# tensor(79.0847, grad_fn=<DivBackward0>)
# tensor(78.8975, grad_fn=<DivBackward0>)
# tensor(78.7112, grad_fn=<DivBackward0>)
# tensor(78.5258, grad_fn=<DivBackward0>)
# tensor(78.3412, grad_fn=<DivBackward0>)
# tensor(78.1575, grad_fn=<DivBackward0>)
# tensor(77.9746, grad_fn=<DivBackward0>)
# tensor(77.7924, grad_fn=<DivBackward0>)
# tensor(77.6112, grad_fn=<DivBackward0>)
# tensor(77.4308, grad_fn=<DivBackward0>)
# tensor(77.2510, grad_fn=<DivBackward0>)
# tensor(77.0721, grad_fn=<DivBackward0>)
# tensor(76.8940, grad_fn=<DivBackward0>)
# tensor(76.7166, grad_fn=<DivBackward0>)
# tensor(76.5401, grad_fn=<DivBackward0>)
# tensor(76.3643, grad_fn=<DivBackward0>)
# tensor(76.1893, grad_fn=<DivBackward0>)
# tensor(76.0150, grad_fn=<DivBackward0>)
# tensor(75.8414, grad_fn=<DivBackward0>)
# tensor(75.6686, grad_fn=<DivBackward0>)
# tensor(75.4966, grad_fn=<DivBackward0>)
# tensor(75.3252, grad_fn=<DivBackward0>)
# tensor(75.1545, grad_fn=<DivBackward0>)
# tensor(74.9845, grad_fn=<DivBackward0>)
# tensor(74.8153, grad_fn=<DivBackward0>)
# tensor(74.6469, grad_fn=<DivBackward0>)
# tensor(74.4790, grad_fn=<DivBackward0>)
# tensor(74.3118, grad_fn=<DivBackward0>)
# tensor(74.1453, grad_fn=<DivBackward0>)
# tensor(73.9796, grad_fn=<DivBackward0>)
# tensor(73.8144, grad_fn=<DivBackward0>)
# tensor(73.6499, grad_fn=<DivBackward0>)
# tensor(73.4861, grad_fn=<DivBackward0>)
# tensor(73.3229, grad_fn=<DivBackward0>)
# tensor(73.1604, grad_fn=<DivBackward0>)
# tensor(72.9984, grad_fn=<DivBackward0>)
# tensor(72.8372, grad_fn=<DivBackward0>)
# tensor(72.6766, grad_fn=<DivBackward0>)
# tensor(72.5166, grad_fn=<DivBackward0>)
# tensor(72.3573, grad_fn=<DivBackward0>)
# tensor(72.1984, grad_fn=<DivBackward0>)
# tensor(72.0403, grad_fn=<DivBackward0>)
# tensor(71.8827, grad_fn=<DivBackward0>)
# tensor(71.7257, grad_fn=<DivBackward0>)
# tensor(71.5694, grad_fn=<DivBackward0>)
# tensor(71.4135, grad_fn=<DivBackward0>)
# tensor(71.2584, grad_fn=<DivBackward0>)
# tensor(71.1037, grad_fn=<DivBackward0>)
# tensor(70.9498, grad_fn=<DivBackward0>)
# tensor(70.7962, grad_fn=<DivBackward0>)
# tensor(70.6432, grad_fn=<DivBackward0>)
# tensor(70.4909, grad_fn=<DivBackward0>)
# tensor(70.3392, grad_fn=<DivBackward0>)
# tensor(70.1879, grad_fn=<DivBackward0>)
# tensor(70.0372, grad_fn=<DivBackward0>)
# tensor(69.8870, grad_fn=<DivBackward0>)
# tensor(69.7374, grad_fn=<DivBackward0>)
# tensor(69.5882, grad_fn=<DivBackward0>)
# tensor(69.4397, grad_fn=<DivBackward0>)
# tensor(69.2917, grad_fn=<DivBackward0>)
# tensor(69.1441, grad_fn=<DivBackward0>)
# tensor(68.9971, grad_fn=<DivBackward0>)
# tensor(68.8506, grad_fn=<DivBackward0>)
# tensor(68.7047, grad_fn=<DivBackward0>)
# tensor(68.5592, grad_fn=<DivBackward0>)
# tensor(68.4142, grad_fn=<DivBackward0>)
# tensor(68.2698, grad_fn=<DivBackward0>)
# tensor(68.1258, grad_fn=<DivBackward0>)
# tensor(67.9823, grad_fn=<DivBackward0>)
# tensor(67.8393, grad_fn=<DivBackward0>)
# tensor(67.6967, grad_fn=<DivBackward0>)
# tensor(67.5547, grad_fn=<DivBackward0>)
# tensor(67.4131, grad_fn=<DivBackward0>)

# %%
np.arange(0.00005,0.001,0.00005)
# Out:
# array([5.0e-05, 1.0e-04, 1.5e-04, 2.0e-04, 2.5e-04, 3.0e-04, 3.5e-04,
#        4.0e-04, 4.5e-04, 5.0e-04, 5.5e-04, 6.0e-04, 6.5e-04, 7.0e-04,
#        7.5e-04, 8.0e-04, 8.5e-04, 9.0e-04, 9.5e-04])

# %%
# Train for 100 epochs
epochs = np.arange(100,500,100)
lr = np.arange(0.00005,0.001,0.00005)

for epoch in epochs:
    for e in range(epoch):
        for l in lr:
            preds = model(inputs)
            loss = mse(preds, targets)
            print(loss)
            loss.backward()
            with torch.no_grad():
                w -= w.grad * 1
                b -= b.grad * 1
                w.grad.zero_()
                b.grad.zero_()
# Out:
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# ...
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)
# tensor(nan, grad_fn=<DivBackward0>)

# %% [markdown]
# Once again, let's verify that the loss is now lower:

# %%
# Calculate loss
preds = model(inputs)
loss = mse(preds, targets)
print(loss)
# Out:
# tensor(35.3998, grad_fn=<DivBackward0>)

# %% [markdown]
# The loss is now much lower than its initial value. Let's look at the model's predictions and compare them with the targets.

# %%
# Predictions
preds
# Out:
# tensor([[ 57.6173,  70.3685],
#         [ 87.2433,  97.3393],
#         [106.5143, 140.4348],
#         [ 23.3764,  38.0908],
#         [109.5073, 112.4987]], grad_fn=<AddBackward0>)

# %%
# Targets
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %% [markdown]
# The predictions are now quite close to the target variables. We can get even better results by training for a few more epochs.
