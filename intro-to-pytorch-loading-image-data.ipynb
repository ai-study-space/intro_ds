# %% [markdown]
# # Loading Image Data
#
# So far we've been working with fairly artificial datasets that you wouldn't typically be using in real projects. Instead, you'll likely be dealing with full-sized images like you'd get from smart phone cameras. In this notebook, we'll look at how to load images and use them to train neural networks.
#
# We'll be using a [dataset of cat and dog photos](https://www.kaggle.com/c/dogs-vs-cats) available from Kaggle. Here are a couple example images:
#
# ![](https://github.com/udacity/deep-learning-v2-pytorch/raw/master/intro-to-pytorch/assets/dog_cat.png)
#
# We'll use this dataset to train a neural network that can differentiate between cats and dogs. These days it doesn't seem like a big accomplishment, but five years ago it was a serious challenge for computer vision systems.

# %% [markdown]
# > #### Here we will use the dataset from Kaggle directly, since it will be a little different from the original notebook, let's first have a try to see how to access the datasets from Kaggle

# %%
import os
print(os.listdir("data/cats_dogs_kaggle"))
# Out:
# ['train.zip', 'test1.zip', 'train', 'test']

# %%
from os import walk
import shutil
for (dirpath, dirnames, filenames) in walk("data/cats_dogs_kaggle"):
    print("Directory path: ", dirpath)
    print("Folder name: ", dirnames)
    
    for filename in filenames:
        if filename.startswith('dog'):
            print("File name: ", filename)
            old_path = dirpath + '/' + filename
            new_path = dirpath + '/dog/' + filename
            shutil.move(old_path, new_path)
        elif filename.startswith('cat'):
            print("File name: ", filename)
            old_path = dirpath + '/' + filename
            new_path = dirpath + '/cat/' + filename
            shutil.move(old_path, new_path)
# Out:
# Directory path:  data/cats_dogs_kaggle
# Folder name:  ['train', 'test']
# Directory path:  data/cats_dogs_kaggle/train
# Folder name:  ['cat', 'dog']
# File name:  cat.0.jpg
# File name:  cat.1.jpg
# File name:  cat.10.jpg
# File name:  cat.100.jpg
# File name:  cat.1000.jpg
# File name:  cat.10000.jpg
# File name:  cat.10001.jpg
# File name:  cat.10002.jpg
# File name:  cat.10003.jpg
# File name:  cat.10004.jpg
# File name:  cat.10005.jpg
# File name:  cat.10006.jpg
# File name:  cat.10007.jpg
# File name:  cat.10008.jpg
# File name:  cat.10009.jpg
# File name:  cat.1001.jpg
# File name:  cat.10010.jpg
# File name:  cat.10011.jpg
# File name:  cat.10012.jpg
# File name:  cat.10013.jpg
# File name:  cat.10014.jpg
# File name:  cat.10015.jpg
# File name:  cat.10016.jpg
# File name:  cat.10017.jpg
# File name:  cat.10018.jpg
# File name:  cat.10019.jpg
# File name:  cat.1002.jpg
# File name:  cat.10020.jpg
# File name:  cat.10021.jpg
# File name:  cat.10022.jpg
# File name:  cat.10023.jpg
# File name:  cat.10024.jpg
# File name:  cat.10025.jpg
# File name:  cat.10026.jpg
# File name:  cat.10027.jpg
# File name:  cat.10028.jpg
# File name:  cat.10029.jpg
# File name:  cat.1003.jpg
# File name:  cat.10030.jpg
# File name:  cat.10031.jpg
# File name:  cat.10032.jpg
# File name:  cat.10033.jpg
# File name:  cat.10034.jpg
# File name:  cat.10035.jpg
# File name:  cat.10036.jpg
# File name:  cat.10037.jpg
# File name:  cat.10038.jpg
# File name:  cat.10039.jpg
# File name:  cat.1004.jpg
# File name:  cat.10040.jpg
# File name:  cat.10041.jpg
# File name:  cat.10042.jpg
# File name:  cat.10043.jpg
# File name:  cat.10044.jpg
# File name:  cat.10045.jpg
# File name:  cat.10046.jpg
# File name:  cat.10047.jpg
# File name:  cat.10048.jpg
# File name:  cat.10049.jpg
# File name:  cat.1005.jpg
# File name:  cat.10050.jpg
# File name:  cat.10051.jpg
# File name:  cat.10052.jpg
# File name:  cat.10053.jpg
# File name:  cat.10054.jpg
# File name:  cat.10055.jpg
# File name:  cat.10056.jpg
# File name:  cat.10057.jpg
# File name:  cat.10058.jpg
# File name:  cat.10059.jpg
# File name:  cat.1006.jpg
# File name:  cat.10060.jpg
# File name:  cat.10061.jpg
# File name:  cat.10062.jpg
# File name:  cat.10063.jpg
# File name:  cat.10064.jpg
# File name:  cat.10065.jpg
# File name:  cat.10066.jpg
# File name:  cat.10067.jpg
# File name:  cat.10068.jpg
# File name:  cat.10069.jpg
# File name:  cat.1007.jpg
# File name:  cat.10070.jpg
# File name:  cat.10071.jpg
# File name:  cat.10072.jpg
# File name:  cat.10073.jpg
# File name:  cat.10074.jpg
# File name:  cat.10075.jpg
# File name:  cat.10076.jpg
# File name:  cat.10077.jpg
# File name:  cat.10078.jpg
# File name:  cat.10079.jpg
# File name:  cat.1008.jpg
# File name:  cat.10080.jpg
# File name:  cat.10081.jpg
# File name:  cat.10082.jpg
# File name:  cat.10083.jpg
# File name:  cat.10084.jpg
# File name:  cat.10085.jpg
# File name:  cat.10086.jpg
# File name:  cat.10087.jpg
# File name:  cat.10088.jpg
# File name:  cat.10089.jpg
# File name:  cat.1009.jpg
# File name:  cat.10090.jpg
# File name:  cat.10091.jpg
# File name:  cat.10092.jpg
# File name:  cat.10093.jpg
# File name:  cat.10094.jpg
# File name:  cat.10095.jpg
# File name:  cat.10096.jpg
# File name:  cat.10097.jpg
# File name:  cat.10098.jpg
# File name:  cat.10099.jpg
# File name:  cat.101.jpg
# File name:  cat.1010.jpg
# File name:  cat.10100.jpg
# File name:  cat.10101.jpg
# File name:  cat.10102.jpg
# File name:  cat.10103.jpg
# File name:  cat.10104.jpg
# File name:  cat.10105.jpg
# File name:  cat.10106.jpg
# File name:  cat.10107.jpg
# File name:  cat.10108.jpg
# File name:  cat.10109.jpg
# File name:  cat.1011.jpg
# File name:  cat.10110.jpg
# File name:  cat.10111.jpg
# File name:  cat.10112.jpg
# File name:  cat.10113.jpg
# File name:  cat.10114.jpg
# File name:  cat.10115.jpg
# File name:  cat.10116.jpg
# File name:  cat.10117.jpg
# File name:  cat.10118.jpg
# File name:  cat.10119.jpg
# File name:  cat.1012.jpg
# File name:  cat.10120.jpg
# File name:  cat.10121.jpg
# File name:  cat.10122.jpg
# File name:  cat.10123.jpg
# File name:  cat.10124.jpg
# File name:  cat.10125.jpg
# File name:  cat.10126.jpg
# File name:  cat.10127.jpg
# File name:  cat.10128.jpg
# File name:  cat.10129.jpg
# File name:  cat.1013.jpg
# File name:  cat.10130.jpg
# File name:  cat.10131.jpg
# File name:  cat.10132.jpg
# File name:  cat.10133.jpg
# File name:  cat.10134.jpg
# File name:  cat.10135.jpg
# File name:  cat.10136.jpg
# File name:  cat.10137.jpg
# File name:  cat.10138.jpg
# File name:  cat.10139.jpg
# File name:  cat.1014.jpg
# File name:  cat.10140.jpg
# File name:  cat.10141.jpg
# File name:  cat.10142.jpg
# File name:  cat.10143.jpg
# File name:  cat.10144.jpg
# File name:  cat.10145.jpg
# File name:  cat.10146.jpg
# File name:  cat.10147.jpg
# File name:  cat.10148.jpg
# File name:  cat.10149.jpg
# File name:  cat.1015.jpg
# File name:  cat.10150.jpg
# File name:  cat.10151.jpg
# File name:  cat.10152.jpg
# File name:  cat.10153.jpg
# File name:  cat.10154.jpg
# File name:  cat.10155.jpg
# File name:  cat.10156.jpg
# File name:  cat.10157.jpg
# File name:  cat.10158.jpg
# File name:  cat.10159.jpg
# File name:  cat.1016.jpg
# File name:  cat.10160.jpg
# File name:  cat.10161.jpg
# File name:  cat.10162.jpg
# File name:  cat.10163.jpg
# File name:  cat.10164.jpg
# File name:  cat.10165.jpg
# File name:  cat.10166.jpg
# File name:  cat.10167.jpg
# File name:  cat.10168.jpg
# File name:  cat.10169.jpg
# File name:  cat.1017.jpg
# File name:  cat.10170.jpg
# File name:  cat.10171.jpg
# File name:  cat.10172.jpg
# File name:  cat.10173.jpg
# File name:  cat.10174.jpg
# File name:  cat.10175.jpg
# File name:  cat.10176.jpg
# File name:  cat.10177.jpg
# File name:  cat.10178.jpg
# File name:  cat.10179.jpg
# File name:  cat.1018.jpg
# File name:  cat.10180.jpg
# File name:  cat.10181.jpg
# File name:  cat.10182.jpg
# File name:  cat.10183.jpg
# File name:  cat.10184.jpg
# File name:  cat.10185.jpg
# File name:  cat.10186.jpg
# File name:  cat.10187.jpg
# File name:  cat.10188.jpg
# File name:  cat.10189.jpg
# File name:  cat.1019.jpg
# File name:  cat.10190.jpg
# File name:  cat.10191.jpg
# File name:  cat.10192.jpg
# File name:  cat.10193.jpg
# File name:  cat.10194.jpg
# File name:  cat.10195.jpg
# File name:  cat.10196.jpg
# File name:  cat.10197.jpg
# File name:  cat.10198.jpg
# File name:  cat.10199.jpg
# File name:  cat.102.jpg
# File name:  cat.1020.jpg
# File name:  cat.10200.jpg
# File name:  cat.10201.jpg
# File name:  cat.10202.jpg
# File name:  cat.10203.jpg
# File name:  cat.10204.jpg
# File name:  cat.10205.jpg
# File name:  cat.10206.jpg
# File name:  cat.10207.jpg
# File name:  cat.10208.jpg
# File name:  cat.10209.jpg
# File name:  cat.1021.jpg
# File name:  cat.10210.jpg
# File name:  cat.10211.jpg
# File name:  cat.10212.jpg
# File name:  cat.10213.jpg
# File name:  cat.10214.jpg
# File name:  cat.10215.jpg
# File name:  cat.10216.jpg
# File name:  cat.10217.jpg
# File name:  cat.10218.jpg
# File name:  cat.10219.jpg
# File name:  cat.1022.jpg
# File name:  cat.10220.jpg
# File name:  cat.10221.jpg
# File name:  cat.10222.jpg
# File name:  cat.10223.jpg
# File name:  cat.10224.jpg
# File name:  cat.10225.jpg
# File name:  cat.10226.jpg
# File name:  cat.10227.jpg
# File name:  cat.10228.jpg
# File name:  cat.10229.jpg
# File name:  cat.1023.jpg
# File name:  cat.10230.jpg
# File name:  cat.10231.jpg
# File name:  cat.10232.jpg
# File name:  cat.10233.jpg
# File name:  cat.10234.jpg
# File name:  cat.10235.jpg
# File name:  cat.10236.jpg
# File name:  cat.10237.jpg
# File name:  cat.10238.jpg
# File name:  cat.10239.jpg
# File name:  cat.1024.jpg
# File name:  cat.10240.jpg
# File name:  cat.10241.jpg
# File name:  cat.10242.jpg
# File name:  cat.10243.jpg
# File name:  cat.10244.jpg
# File name:  cat.10245.jpg
# File name:  cat.10246.jpg
# File name:  cat.10247.jpg
# File name:  cat.10248.jpg
# File name:  cat.10249.jpg
# File name:  cat.1025.jpg
# File name:  cat.10250.jpg
# File name:  cat.10251.jpg
# File name:  cat.10252.jpg
# File name:  cat.10253.jpg
# File name:  cat.10254.jpg
# File name:  cat.10255.jpg
# File name:  cat.10256.jpg
# File name:  cat.10257.jpg
# File name:  cat.10258.jpg
# File name:  cat.10259.jpg
# File name:  cat.1026.jpg
# File name:  cat.10260.jpg
# File name:  cat.10261.jpg
# File name:  cat.10262.jpg
# File name:  cat.10263.jpg
# File name:  cat.10264.jpg
# File name:  cat.10265.jpg
# File name:  cat.10266.jpg
# File name:  cat.10267.jpg
# File name:  cat.10268.jpg
# File name:  cat.10269.jpg
# File name:  cat.1027.jpg
# File name:  cat.10270.jpg
# File name:  cat.10271.jpg
# File name:  cat.10272.jpg
# File name:  cat.10273.jpg
# File name:  cat.10274.jpg
# File name:  cat.10275.jpg
# File name:  cat.10276.jpg
# File name:  cat.10277.jpg
# File name:  cat.10278.jpg
# File name:  cat.10279.jpg
# File name:  cat.1028.jpg
# File name:  cat.10280.jpg
# File name:  cat.10281.jpg
# File name:  cat.10282.jpg
# File name:  cat.10283.jpg
# File name:  cat.10284.jpg
# File name:  cat.10285.jpg
# File name:  cat.10286.jpg
# File name:  cat.10287.jpg
# File name:  cat.10288.jpg
# File name:  cat.10289.jpg
# File name:  cat.1029.jpg
# File name:  cat.10290.jpg
# File name:  cat.10291.jpg
# File name:  cat.10292.jpg
# File name:  cat.10293.jpg
# File name:  cat.10294.jpg
# File name:  cat.10295.jpg
# File name:  cat.10296.jpg
# File name:  cat.10297.jpg
# File name:  cat.10298.jpg
# File name:  cat.10299.jpg
# File name:  cat.103.jpg
# File name:  cat.1030.jpg
# File name:  cat.10300.jpg
# File name:  cat.10301.jpg
# File name:  cat.10302.jpg
# File name:  cat.10303.jpg
# File name:  cat.10304.jpg
# File name:  cat.10305.jpg
# File name:  cat.10306.jpg
# File name:  cat.10307.jpg
# File name:  cat.10308.jpg
# File name:  cat.10309.jpg
# File name:  cat.1031.jpg
# File name:  cat.10310.jpg
# File name:  cat.10311.jpg
# File name:  cat.10312.jpg
# File name:  cat.10313.jpg
# File name:  cat.10314.jpg
# File name:  cat.10315.jpg
# File name:  cat.10316.jpg
# File name:  cat.10317.jpg
# File name:  cat.10318.jpg
# File name:  cat.10319.jpg
# File name:  cat.1032.jpg
# File name:  cat.10320.jpg
# File name:  cat.10321.jpg
# File name:  cat.10322.jpg
# File name:  cat.10323.jpg
# File name:  cat.10324.jpg
# File name:  cat.10325.jpg
# File name:  cat.10326.jpg
# File name:  cat.10327.jpg
# File name:  cat.10328.jpg
# File name:  cat.10329.jpg
# File name:  cat.1033.jpg
# File name:  cat.10330.jpg
# File name:  cat.10331.jpg
# File name:  cat.10332.jpg
# File name:  cat.10333.jpg
# File name:  cat.10334.jpg
# File name:  cat.10335.jpg
# File name:  cat.10336.jpg
# File name:  cat.10337.jpg
# File name:  cat.10338.jpg
# File name:  cat.10339.jpg
# File name:  cat.1034.jpg
# File name:  cat.10340.jpg
# File name:  cat.10341.jpg
# File name:  cat.10342.jpg
# File name:  cat.10343.jpg
# File name:  cat.10344.jpg
# File name:  cat.10345.jpg
# File name:  cat.10346.jpg
# File name:  cat.10347.jpg
# File name:  cat.10348.jpg
# File name:  cat.10349.jpg
# File name:  cat.1035.jpg
# File name:  cat.10350.jpg
# File name:  cat.10351.jpg
# File name:  cat.10352.jpg
# File name:  cat.10353.jpg
# File name:  cat.10354.jpg
# File name:  cat.10355.jpg
# File name:  cat.10356.jpg
# File name:  cat.10357.jpg
# File name:  cat.10358.jpg
# File name:  cat.10359.jpg
# File name:  cat.1036.jpg
# File name:  cat.10360.jpg
# File name:  cat.10361.jpg
# File name:  cat.10362.jpg
# File name:  cat.10363.jpg
# File name:  cat.10364.jpg
# File name:  cat.10365.jpg
# File name:  cat.10366.jpg
# File name:  cat.10367.jpg
# File name:  cat.10368.jpg
# File name:  cat.10369.jpg
# File name:  cat.1037.jpg
# File name:  cat.10370.jpg
# File name:  cat.10371.jpg
# File name:  cat.10372.jpg
# File name:  cat.10373.jpg
# File name:  cat.10374.jpg
# File name:  cat.10375.jpg
# File name:  cat.10376.jpg
# File name:  cat.10377.jpg
# File name:  cat.10378.jpg
# File name:  cat.10379.jpg
# File name:  cat.1038.jpg
# File name:  cat.10380.jpg
# File name:  cat.10381.jpg
# File name:  cat.10382.jpg
# File name:  cat.10383.jpg
# File name:  cat.10384.jpg
# File name:  cat.10385.jpg
# File name:  cat.10386.jpg
# File name:  cat.10387.jpg
# File name:  cat.10388.jpg
# File name:  cat.10389.jpg
# File name:  cat.1039.jpg
# File name:  cat.10390.jpg
# File name:  cat.10391.jpg
# File name:  cat.10392.jpg
# File name:  cat.10393.jpg
# File name:  cat.10394.jpg
# File name:  cat.10395.jpg
# File name:  cat.10396.jpg
# File name:  cat.10397.jpg
# File name:  cat.10398.jpg
# File name:  cat.10399.jpg
# File name:  cat.104.jpg
# File name:  cat.1040.jpg
# File name:  cat.10400.jpg
# File name:  cat.10401.jpg
# File name:  cat.10402.jpg
# File name:  cat.10403.jpg
# File name:  cat.10404.jpg
# File name:  cat.10405.jpg
# File name:  cat.10406.jpg
# File name:  cat.10407.jpg
# File name:  cat.10408.jpg
# File name:  cat.10409.jpg
# File name:  cat.1041.jpg
# File name:  cat.10410.jpg
# File name:  cat.10411.jpg
# File name:  cat.10412.jpg
# File name:  cat.10413.jpg
# File name:  cat.10414.jpg
# File name:  cat.10415.jpg
# File name:  cat.10416.jpg
# File name:  cat.10417.jpg
# File name:  cat.10418.jpg
# File name:  cat.10419.jpg
# File name:  cat.1042.jpg
# File name:  cat.10420.jpg
# File name:  cat.10421.jpg
# File name:  cat.10422.jpg
# File name:  cat.10423.jpg
# File name:  cat.10424.jpg
# File name:  cat.10425.jpg
# File name:  cat.10426.jpg
# File name:  cat.10427.jpg
# File name:  cat.10428.jpg
# File name:  cat.10429.jpg
# File name:  cat.1043.jpg
# File name:  cat.10430.jpg
# File name:  cat.10431.jpg
# File name:  cat.10432.jpg
# File name:  cat.10433.jpg
# File name:  cat.10434.jpg
# File name:  cat.10435.jpg
# File name:  cat.10436.jpg
# File name:  cat.10437.jpg
# File name:  cat.10438.jpg
# File name:  cat.10439.jpg
# File name:  cat.1044.jpg
# File name:  cat.10440.jpg
# File name:  cat.10441.jpg
# File name:  cat.10442.jpg
# File name:  cat.10443.jpg
# File name:  cat.10444.jpg
# File name:  cat.10445.jpg
# File name:  cat.10446.jpg
# File name:  cat.10447.jpg
# File name:  cat.10448.jpg
# File name:  cat.10449.jpg
# File name:  cat.1045.jpg
# File name:  cat.10450.jpg
# File name:  cat.10451.jpg
# File name:  cat.10452.jpg
# File name:  cat.10453.jpg
# File name:  cat.10454.jpg
# File name:  cat.10455.jpg
# File name:  cat.10456.jpg
# File name:  cat.10457.jpg
# File name:  cat.10458.jpg
# File name:  cat.10459.jpg
# File name:  cat.1046.jpg
# File name:  cat.10460.jpg
# File name:  cat.10461.jpg
# File name:  cat.10462.jpg
# File name:  cat.10463.jpg
# File name:  cat.10464.jpg
# File name:  cat.10465.jpg
# File name:  cat.10466.jpg
# File name:  cat.10467.jpg
# File name:  cat.10468.jpg
# File name:  cat.10469.jpg
# File name:  cat.1047.jpg
# File name:  cat.10470.jpg
# File name:  cat.10471.jpg
# File name:  cat.10472.jpg
# File name:  cat.10473.jpg
# File name:  cat.10474.jpg
# File name:  cat.10475.jpg
# File name:  cat.10476.jpg
# File name:  cat.10477.jpg
# File name:  cat.10478.jpg
# File name:  cat.10479.jpg
# File name:  cat.1048.jpg
# File name:  cat.10480.jpg
# File name:  cat.10481.jpg
# File name:  cat.10482.jpg
# File name:  cat.10483.jpg
# File name:  cat.10484.jpg
# File name:  cat.10485.jpg
# File name:  cat.10486.jpg
# File name:  cat.10487.jpg
# File name:  cat.10488.jpg
# File name:  cat.10489.jpg
# File name:  cat.1049.jpg
# File name:  cat.10490.jpg
# File name:  cat.10491.jpg
# File name:  cat.10492.jpg
# File name:  cat.10493.jpg
# File name:  cat.10494.jpg
# File name:  cat.10495.jpg
# File name:  cat.10496.jpg
# File name:  cat.10497.jpg
# File name:  cat.10498.jpg
# File name:  cat.10499.jpg
# File name:  cat.105.jpg
# File name:  cat.1050.jpg
# File name:  cat.10500.jpg
# File name:  cat.10501.jpg
# File name:  cat.10502.jpg
# File name:  cat.10503.jpg
# File name:  cat.10504.jpg
# File name:  cat.10505.jpg
# File name:  cat.10506.jpg
# File name:  cat.10507.jpg
# File name:  cat.10508.jpg
# File name:  cat.10509.jpg
# File name:  cat.1051.jpg
# File name:  cat.10510.jpg
# File name:  cat.10511.jpg
# File name:  cat.10512.jpg
# File name:  cat.10513.jpg
# File name:  cat.10514.jpg
# File name:  cat.10515.jpg
# File name:  cat.10516.jpg
# File name:  cat.10517.jpg
# File name:  cat.10518.jpg
# File name:  cat.10519.jpg
# File name:  cat.1052.jpg
# File name:  cat.10520.jpg
# File name:  cat.10521.jpg
# File name:  cat.10522.jpg
# File name:  cat.10523.jpg
# File name:  cat.10524.jpg
# File name:  cat.10525.jpg
# File name:  cat.10526.jpg
# File name:  cat.10527.jpg
# File name:  cat.10528.jpg
# File name:  cat.10529.jpg
# File name:  cat.1053.jpg
# File name:  cat.10530.jpg
# File name:  cat.10531.jpg
# File name:  cat.10532.jpg
# File name:  cat.10533.jpg
# File name:  cat.10534.jpg
# File name:  cat.10535.jpg
# File name:  cat.10536.jpg
# File name:  cat.10537.jpg
# File name:  cat.10538.jpg
# File name:  cat.10539.jpg
# File name:  cat.1054.jpg
# File name:  cat.10540.jpg
# File name:  cat.10541.jpg
# File name:  cat.10542.jpg
# File name:  cat.10543.jpg
# File name:  cat.10544.jpg
# File name:  cat.10545.jpg
# File name:  cat.10546.jpg
# File name:  cat.10547.jpg
# File name:  cat.10548.jpg
# File name:  cat.10549.jpg
# File name:  cat.1055.jpg
# File name:  cat.10550.jpg
# File name:  cat.10551.jpg
# File name:  cat.10552.jpg
# File name:  cat.10553.jpg
# File name:  cat.10554.jpg
# File name:  cat.10555.jpg
# File name:  cat.10556.jpg
# File name:  cat.10557.jpg
# File name:  cat.10558.jpg
# File name:  cat.10559.jpg
# File name:  cat.1056.jpg
# File name:  cat.10560.jpg
# File name:  cat.10561.jpg
# File name:  cat.10562.jpg
# File name:  cat.10563.jpg
# File name:  cat.10564.jpg
# File name:  cat.10565.jpg
# File name:  cat.10566.jpg
# File name:  cat.10567.jpg
# File name:  cat.10568.jpg
# File name:  cat.10569.jpg
# File name:  cat.1057.jpg
# File name:  cat.10570.jpg
# File name:  cat.10571.jpg
# File name:  cat.10572.jpg
# File name:  cat.10573.jpg
# File name:  cat.10574.jpg
# File name:  cat.10575.jpg
# File name:  cat.10576.jpg
# File name:  cat.10577.jpg
# File name:  cat.10578.jpg
# File name:  cat.10579.jpg
# File name:  cat.1058.jpg
# File name:  cat.10580.jpg
# File name:  cat.10581.jpg
# File name:  cat.10582.jpg
# File name:  cat.10583.jpg
# File name:  cat.10584.jpg
# File name:  cat.10585.jpg
# File name:  cat.10586.jpg
# File name:  cat.10587.jpg
# File name:  cat.10588.jpg
# File name:  cat.10589.jpg
# File name:  cat.1059.jpg
# File name:  cat.10590.jpg
# File name:  cat.10591.jpg
# File name:  cat.10592.jpg
# File name:  cat.10593.jpg
# File name:  cat.10594.jpg
# File name:  cat.10595.jpg
# File name:  cat.10596.jpg
# File name:  cat.10597.jpg
# File name:  cat.10598.jpg
# File name:  cat.10599.jpg
# File name:  cat.106.jpg
# File name:  cat.1060.jpg
# File name:  cat.10600.jpg
# File name:  cat.10601.jpg
# File name:  cat.10602.jpg
# File name:  cat.10603.jpg
# File name:  cat.10604.jpg
# File name:  cat.10605.jpg
# File name:  cat.10606.jpg
# File name:  cat.10607.jpg
# File name:  cat.10608.jpg
# File name:  cat.10609.jpg
# File name:  cat.1061.jpg
# File name:  cat.10610.jpg
# File name:  cat.10611.jpg
# File name:  cat.10612.jpg
# File name:  cat.10613.jpg
# File name:  cat.10614.jpg
# File name:  cat.10615.jpg
# File name:  cat.10616.jpg
# File name:  cat.10617.jpg
# File name:  cat.10618.jpg
# File name:  cat.10619.jpg
# File name:  cat.1062.jpg
# File name:  cat.10620.jpg
# File name:  cat.10621.jpg
# File name:  cat.10622.jpg
# File name:  cat.10623.jpg
# File name:  cat.10624.jpg
# File name:  cat.10625.jpg
# File name:  cat.10626.jpg
# File name:  cat.10627.jpg
# File name:  cat.10628.jpg
# File name:  cat.10629.jpg
# File name:  cat.1063.jpg
# File name:  cat.10630.jpg
# File name:  cat.10631.jpg
# File name:  cat.10632.jpg
# File name:  cat.10633.jpg
# File name:  cat.10634.jpg
# File name:  cat.10635.jpg
# File name:  cat.10636.jpg
# File name:  cat.10637.jpg
# File name:  cat.10638.jpg
# File name:  cat.10639.jpg
# File name:  cat.1064.jpg
# File name:  cat.10640.jpg
# File name:  cat.10641.jpg
# File name:  cat.10642.jpg
# File name:  cat.10643.jpg
# File name:  cat.10644.jpg
# File name:  cat.10645.jpg
# File name:  cat.10646.jpg
# File name:  cat.10647.jpg
# File name:  cat.10648.jpg
# File name:  cat.10649.jpg
# File name:  cat.1065.jpg
# File name:  cat.10650.jpg
# File name:  cat.10651.jpg
# File name:  cat.10652.jpg
# File name:  cat.10653.jpg
# File name:  cat.10654.jpg
# File name:  cat.10655.jpg
# File name:  cat.10656.jpg
# File name:  cat.10657.jpg
# File name:  cat.10658.jpg
# File name:  cat.10659.jpg
# File name:  cat.1066.jpg
# File name:  cat.10660.jpg
# File name:  cat.10661.jpg
# File name:  cat.10662.jpg
# File name:  cat.10663.jpg
# File name:  cat.10664.jpg
# File name:  cat.10665.jpg
# File name:  cat.10666.jpg
# File name:  cat.10667.jpg
# File name:  cat.10668.jpg
# File name:  cat.10669.jpg
# File name:  cat.1067.jpg
# File name:  cat.10670.jpg
# File name:  cat.10671.jpg
# File name:  cat.10672.jpg
# File name:  cat.10673.jpg
# File name:  cat.10674.jpg
# File name:  cat.10675.jpg
# File name:  cat.10676.jpg
# File name:  cat.10677.jpg
# File name:  cat.10678.jpg
# File name:  cat.10679.jpg
# File name:  cat.1068.jpg
# File name:  cat.10680.jpg
# File name:  cat.10681.jpg
# File name:  cat.10682.jpg
# File name:  cat.10683.jpg
# File name:  cat.10684.jpg
# File name:  cat.10685.jpg
# File name:  cat.10686.jpg
# File name:  cat.10687.jpg
# File name:  cat.10688.jpg
# File name:  cat.10689.jpg
# File name:  cat.1069.jpg
# File name:  cat.10690.jpg
# File name:  cat.10691.jpg
# File name:  cat.10692.jpg
# File name:  cat.10693.jpg
# File name:  cat.10694.jpg
# File name:  cat.10695.jpg
# File name:  cat.10696.jpg
# File name:  cat.10697.jpg
# File name:  cat.10698.jpg
# File name:  cat.10699.jpg
# File name:  cat.107.jpg
# File name:  cat.1070.jpg
# File name:  cat.10700.jpg
# File name:  cat.10701.jpg
# File name:  cat.10702.jpg
# File name:  cat.10703.jpg
# File name:  cat.10704.jpg
# File name:  cat.10705.jpg
# File name:  cat.10706.jpg
# File name:  cat.10707.jpg
# File name:  cat.10708.jpg
# File name:  cat.10709.jpg
# File name:  cat.1071.jpg
# File name:  cat.10710.jpg
# File name:  cat.10711.jpg
# File name:  cat.10712.jpg
# File name:  cat.10713.jpg
# File name:  cat.10714.jpg
# File name:  cat.10715.jpg
# File name:  cat.10716.jpg
# File name:  cat.10717.jpg
# File name:  cat.10718.jpg
# File name:  cat.10719.jpg
# File name:  cat.1072.jpg
# File name:  cat.10720.jpg
# File name:  cat.10721.jpg
# File name:  cat.10722.jpg
# File name:  cat.10723.jpg
# File name:  cat.10724.jpg
# File name:  cat.10725.jpg
# File name:  cat.10726.jpg
# File name:  cat.10727.jpg
# File name:  cat.10728.jpg
# File name:  cat.10729.jpg
# File name:  cat.1073.jpg
# File name:  cat.10730.jpg
# File name:  cat.10731.jpg
# File name:  cat.10732.jpg
# File name:  cat.10733.jpg
# File name:  cat.10734.jpg
# File name:  cat.10735.jpg
# File name:  cat.10736.jpg
# File name:  cat.10737.jpg
# File name:  cat.10738.jpg
# File name:  cat.10739.jpg
# File name:  cat.1074.jpg
# File name:  cat.10740.jpg
# File name:  cat.10741.jpg
# File name:  cat.10742.jpg
# File name:  cat.10743.jpg
# File name:  cat.10744.jpg
# File name:  cat.10745.jpg
# File name:  cat.10746.jpg
# File name:  cat.10747.jpg
# File name:  cat.10748.jpg
# File name:  cat.10749.jpg
# File name:  cat.1075.jpg
# File name:  cat.10750.jpg
# File name:  cat.10751.jpg
# File name:  cat.10752.jpg
# File name:  cat.10753.jpg
# File name:  cat.10754.jpg
# File name:  cat.10755.jpg
# File name:  cat.10756.jpg
# File name:  cat.10757.jpg
# File name:  cat.10758.jpg
# File name:  cat.10759.jpg
# File name:  cat.1076.jpg
# File name:  cat.10760.jpg
# File name:  cat.10761.jpg
# File name:  cat.10762.jpg
# File name:  cat.10763.jpg
# File name:  cat.10764.jpg
# File name:  cat.10765.jpg
# File name:  cat.10766.jpg
# File name:  cat.10767.jpg
# File name:  cat.10768.jpg
# File name:  cat.10769.jpg
# File name:  cat.1077.jpg
# File name:  cat.10770.jpg
# File name:  cat.10771.jpg
# File name:  cat.10772.jpg
# File name:  cat.10773.jpg
# File name:  cat.10774.jpg
# File name:  cat.10775.jpg
# File name:  cat.10776.jpg
# File name:  cat.10777.jpg
# File name:  cat.10778.jpg
# File name:  cat.10779.jpg
# File name:  cat.1078.jpg
# File name:  cat.10780.jpg
# File name:  cat.10781.jpg
# File name:  cat.10782.jpg
# File name:  cat.10783.jpg
# File name:  cat.10784.jpg
# File name:  cat.10785.jpg
# File name:  cat.10786.jpg
# File name:  cat.10787.jpg
# File name:  cat.10788.jpg
# File name:  cat.10789.jpg
# File name:  cat.1079.jpg
# File name:  cat.10790.jpg
# File name:  cat.10791.jpg
# File name:  cat.10792.jpg
# File name:  cat.10793.jpg
# File name:  cat.10794.jpg
# File name:  cat.10795.jpg
# File name:  cat.10796.jpg
# File name:  cat.10797.jpg
# File name:  cat.10798.jpg
# File name:  cat.10799.jpg
# File name:  cat.108.jpg
# File name:  cat.1080.jpg
# File name:  cat.10800.jpg
# File name:  cat.10801.jpg
# File name:  cat.10802.jpg
# File name:  cat.10803.jpg
# File name:  cat.10804.jpg
# File name:  cat.10805.jpg
# File name:  cat.10806.jpg
# File name:  cat.10807.jpg
# File name:  cat.10808.jpg
# File name:  cat.10809.jpg
# File name:  cat.1081.jpg
# File name:  cat.10810.jpg
# File name:  cat.10811.jpg
# File name:  cat.10812.jpg
# File name:  cat.10813.jpg
# File name:  cat.10814.jpg
# File name:  cat.10815.jpg
# File name:  cat.10816.jpg
# File name:  cat.10817.jpg
# File name:  cat.10818.jpg
# File name:  cat.10819.jpg
# File name:  cat.1082.jpg
# File name:  cat.10820.jpg
# File name:  cat.10821.jpg
# File name:  cat.10822.jpg
# File name:  cat.10823.jpg
# File name:  cat.10824.jpg
# File name:  cat.10825.jpg
# File name:  cat.10826.jpg
# File name:  cat.10827.jpg
# File name:  cat.10828.jpg
# File name:  cat.10829.jpg
# File name:  cat.1083.jpg
# File name:  cat.10830.jpg
# File name:  cat.10831.jpg
# File name:  cat.10832.jpg
# File name:  cat.10833.jpg
# File name:  cat.10834.jpg
# File name:  cat.10835.jpg
# File name:  cat.10836.jpg
# File name:  cat.10837.jpg
# File name:  cat.10838.jpg
# File name:  cat.10839.jpg
# File name:  cat.1084.jpg
# File name:  cat.10840.jpg
# File name:  cat.10841.jpg
# File name:  cat.10842.jpg
# File name:  cat.10843.jpg
# File name:  cat.10844.jpg
# File name:  cat.10845.jpg
# File name:  cat.10846.jpg
# File name:  cat.10847.jpg
# File name:  cat.10848.jpg
# File name:  cat.10849.jpg
# File name:  cat.1085.jpg
# File name:  cat.10850.jpg
# File name:  cat.10851.jpg
# File name:  cat.10852.jpg
# File name:  cat.10853.jpg
# File name:  cat.10854.jpg
# File name:  cat.10855.jpg
# File name:  cat.10856.jpg
# File name:  cat.10857.jpg
# File name:  cat.10858.jpg
# File name:  cat.10859.jpg
# File name:  cat.1086.jpg
# File name:  cat.10860.jpg
# File name:  cat.10861.jpg
# File name:  cat.10862.jpg
# File name:  cat.10863.jpg
# File name:  cat.10864.jpg
# File name:  cat.10865.jpg
# File name:  cat.10866.jpg
# File name:  cat.10867.jpg
# File name:  cat.10868.jpg
# File name:  cat.10869.jpg
# File name:  cat.1087.jpg
# File name:  cat.10870.jpg
# File name:  cat.10871.jpg
# File name:  cat.10872.jpg
# File name:  cat.10873.jpg
# File name:  cat.10874.jpg
# File name:  cat.10875.jpg
# File name:  cat.10876.jpg
# File name:  cat.10877.jpg
# File name:  cat.10878.jpg
# File name:  cat.10879.jpg
# File name:  cat.1088.jpg
# File name:  cat.10880.jpg
# File name:  cat.10881.jpg
# File name:  cat.10882.jpg
# File name:  cat.10883.jpg
# File name:  cat.10884.jpg
# File name:  cat.10885.jpg
# File name:  cat.10886.jpg
# File name:  cat.10887.jpg
# File name:  cat.10888.jpg
# File name:  cat.10889.jpg
# File name:  cat.1089.jpg
# File name:  cat.10890.jpg
# File name:  cat.10891.jpg
# File name:  cat.10892.jpg
# File name:  cat.10893.jpg
# File name:  cat.10894.jpg
# File name:  cat.10895.jpg
# File name:  cat.10896.jpg
# File name:  cat.10897.jpg
# File name:  cat.10898.jpg
# File name:  cat.10899.jpg
# File name:  cat.109.jpg
# File name:  cat.1090.jpg
# File name:  cat.10900.jpg
# File name:  cat.10901.jpg
# File name:  cat.10902.jpg
# File name:  cat.10903.jpg
# File name:  cat.10904.jpg
# File name:  cat.10905.jpg
# File name:  cat.10906.jpg
# File name:  cat.10907.jpg
# File name:  cat.10908.jpg
# File name:  cat.10909.jpg
# File name:  cat.1091.jpg
# File name:  cat.10910.jpg
# File name:  cat.10911.jpg
# File name:  cat.10912.jpg
# File name:  cat.10913.jpg
# File name:  cat.10914.jpg
# File name:  cat.10915.jpg
# File name:  cat.10916.jpg
# File name:  cat.10917.jpg
# File name:  cat.10918.jpg
# File name:  cat.10919.jpg
# File name:  cat.1092.jpg
# File name:  cat.10920.jpg
# File name:  cat.10921.jpg
# File name:  cat.10922.jpg
# File name:  cat.10923.jpg
# File name:  cat.10924.jpg
# File name:  cat.10925.jpg
# File name:  cat.10926.jpg
# File name:  cat.10927.jpg
# File name:  cat.10928.jpg
# File name:  cat.10929.jpg
# File name:  cat.1093.jpg
# File name:  cat.10930.jpg
# File name:  cat.10931.jpg
# File name:  cat.10932.jpg
# File name:  cat.10933.jpg
# File name:  cat.10934.jpg
# File name:  cat.10935.jpg
# File name:  cat.10936.jpg
# File name:  cat.10937.jpg
# File name:  cat.10938.jpg
# File name:  cat.10939.jpg
# File name:  cat.1094.jpg
# File name:  cat.10940.jpg
# File name:  cat.10941.jpg
# File name:  cat.10942.jpg
# File name:  cat.10943.jpg
# File name:  cat.10944.jpg
# File name:  cat.10945.jpg
# File name:  cat.10946.jpg
# File name:  cat.10947.jpg
# File name:  cat.10948.jpg
# File name:  cat.10949.jpg
# File name:  cat.1095.jpg
# File name:  cat.10950.jpg
# File name:  cat.10951.jpg
# File name:  cat.10952.jpg
# File name:  cat.10953.jpg
# File name:  cat.10954.jpg
# File name:  cat.10955.jpg
# File name:  cat.10956.jpg
# File name:  cat.10957.jpg
# File name:  cat.10958.jpg
# File name:  cat.10959.jpg
# File name:  cat.1096.jpg
# File name:  cat.10960.jpg
# File name:  cat.10961.jpg
# File name:  cat.10962.jpg
# File name:  cat.10963.jpg
# File name:  cat.10964.jpg
# File name:  cat.10965.jpg
# File name:  cat.10966.jpg
# File name:  cat.10967.jpg
# File name:  cat.10968.jpg
# File name:  cat.10969.jpg
# File name:  cat.1097.jpg
# File name:  cat.10970.jpg
# File name:  cat.10971.jpg
# File name:  cat.10972.jpg
# File name:  cat.10973.jpg
# File name:  cat.10974.jpg
# File name:  cat.10975.jpg
# File name:  cat.10976.jpg
# File name:  cat.10977.jpg
# File name:  cat.10978.jpg
# File name:  cat.10979.jpg
# File name:  cat.1098.jpg
# File name:  cat.10980.jpg
# File name:  cat.10981.jpg
# File name:  cat.10982.jpg
# File name:  cat.10983.jpg
# File name:  cat.10984.jpg
# File name:  cat.10985.jpg
# File name:  cat.10986.jpg
# File name:  cat.10987.jpg
# File name:  cat.10988.jpg
# File name:  cat.10989.jpg
# File name:  cat.1099.jpg
# File name:  cat.10990.jpg
# File name:  cat.10991.jpg
# File name:  cat.10992.jpg
# File name:  cat.10993.jpg
# File name:  cat.10994.jpg
# File name:  cat.10995.jpg
# File name:  cat.10996.jpg
# File name:  cat.10997.jpg
# File name:  cat.10998.jpg
# File name:  cat.10999.jpg
# File name:  cat.11.jpg
# File name:  cat.110.jpg
# File name:  cat.1100.jpg
# File name:  cat.11000.jpg
# File name:  cat.11001.jpg
# File name:  cat.11002.jpg
# File name:  cat.11003.jpg
# File name:  cat.11004.jpg
# File name:  cat.11005.jpg
# File name:  cat.11006.jpg
# File name:  cat.11007.jpg
# File name:  cat.11008.jpg
# File name:  cat.11009.jpg
# File name:  cat.1101.jpg
# File name:  cat.11010.jpg
# File name:  cat.11011.jpg
# File name:  cat.11012.jpg
# File name:  cat.11013.jpg
# File name:  cat.11014.jpg
# File name:  cat.11015.jpg
# File name:  cat.11016.jpg
# File name:  cat.11017.jpg
# File name:  cat.11018.jpg
# File name:  cat.11019.jpg
# File name:  cat.1102.jpg
# File name:  cat.11020.jpg
# File name:  cat.11021.jpg
# File name:  cat.11022.jpg
# File name:  cat.11023.jpg
# File name:  cat.11024.jpg
# File name:  cat.11025.jpg
# File name:  cat.11026.jpg
# File name:  cat.11027.jpg
# File name:  cat.11028.jpg
# File name:  cat.11029.jpg
# File name:  cat.1103.jpg
# File name:  cat.11030.jpg
# File name:  cat.11031.jpg
# File name:  cat.11032.jpg
# File name:  cat.11033.jpg
# File name:  cat.11034.jpg
# File name:  cat.11035.jpg
# File name:  cat.11036.jpg
# File name:  cat.11037.jpg
# File name:  cat.11038.jpg
# File name:  cat.11039.jpg
# File name:  cat.1104.jpg
# File name:  cat.11040.jpg
# File name:  cat.11041.jpg
# File name:  cat.11042.jpg
# File name:  cat.11043.jpg
# File name:  cat.11044.jpg
# File name:  cat.11045.jpg
# File name:  cat.11046.jpg
# File name:  cat.11047.jpg
# File name:  cat.11048.jpg
# File name:  cat.11049.jpg
# File name:  cat.1105.jpg
# File name:  cat.11050.jpg
# File name:  cat.11051.jpg
# File name:  cat.11052.jpg
# File name:  cat.11053.jpg
# File name:  cat.11054.jpg
# File name:  cat.11055.jpg
# File name:  cat.11056.jpg
# File name:  cat.11057.jpg
# File name:  cat.11058.jpg
# File name:  cat.11059.jpg
# File name:  cat.1106.jpg
# File name:  cat.11060.jpg
# File name:  cat.11061.jpg
# File name:  cat.11062.jpg
# File name:  cat.11063.jpg
# File name:  cat.11064.jpg
# File name:  cat.11065.jpg
# File name:  cat.11066.jpg
# File name:  cat.11067.jpg
# File name:  cat.11068.jpg
# File name:  cat.11069.jpg
# File name:  cat.1107.jpg
# File name:  cat.11070.jpg
# File name:  cat.11071.jpg
# File name:  cat.11072.jpg
# File name:  cat.11073.jpg
# File name:  cat.11074.jpg
# File name:  cat.11075.jpg
# File name:  cat.11076.jpg
# File name:  cat.11077.jpg
# File name:  cat.11078.jpg
# File name:  cat.11079.jpg
# File name:  cat.1108.jpg
# File name:  cat.11080.jpg
# File name:  cat.11081.jpg
# File name:  cat.11082.jpg
# File name:  cat.11083.jpg
# File name:  cat.11084.jpg
# File name:  cat.11085.jpg
# File name:  cat.11086.jpg
# File name:  cat.11087.jpg
# File name:  cat.11088.jpg
# File name:  cat.11089.jpg
# File name:  cat.1109.jpg
# File name:  cat.11090.jpg
# File name:  cat.11091.jpg
# File name:  cat.11092.jpg
# File name:  cat.11093.jpg
# File name:  cat.11094.jpg
# File name:  cat.11095.jpg
# File name:  cat.11096.jpg
# File name:  cat.11097.jpg
# File name:  cat.11098.jpg
# File name:  cat.11099.jpg
# File name:  cat.111.jpg
# File name:  cat.1110.jpg
# File name:  cat.11100.jpg
# File name:  cat.11101.jpg
# File name:  cat.11102.jpg
# File name:  cat.11103.jpg
# File name:  cat.11104.jpg
# File name:  cat.11105.jpg
# File name:  cat.11106.jpg
# File name:  cat.11107.jpg
# File name:  cat.11108.jpg
# File name:  cat.11109.jpg
# File name:  cat.1111.jpg
# File name:  cat.11110.jpg
# File name:  cat.11111.jpg
# File name:  cat.11112.jpg
# File name:  cat.11113.jpg
# File name:  cat.11114.jpg
# File name:  cat.11115.jpg
# File name:  cat.11116.jpg
# File name:  cat.11117.jpg
# File name:  cat.11118.jpg
# File name:  cat.11119.jpg
# File name:  cat.1112.jpg
# File name:  cat.11120.jpg
# File name:  cat.11121.jpg
# File name:  cat.11122.jpg
# File name:  cat.11123.jpg
# File name:  cat.11124.jpg
# File name:  cat.11125.jpg
# File name:  cat.11126.jpg
# File name:  cat.11127.jpg
# File name:  cat.11128.jpg
# File name:  cat.11129.jpg
# File name:  cat.1113.jpg
# File name:  cat.11130.jpg
# File name:  cat.11131.jpg
# File name:  cat.11132.jpg
# File name:  cat.11133.jpg
# File name:  cat.11134.jpg
# File name:  cat.11135.jpg
# File name:  cat.11136.jpg
# File name:  cat.11137.jpg
# File name:  cat.11138.jpg
# File name:  cat.11139.jpg
# File name:  cat.1114.jpg
# File name:  cat.11140.jpg
# File name:  cat.11141.jpg
# File name:  cat.11142.jpg
# File name:  cat.11143.jpg
# File name:  cat.11144.jpg
# File name:  cat.11145.jpg
# File name:  cat.11146.jpg
# File name:  cat.11147.jpg
# File name:  cat.11148.jpg
# File name:  cat.11149.jpg
# File name:  cat.1115.jpg
# File name:  cat.11150.jpg
# File name:  cat.11151.jpg
# File name:  cat.11152.jpg
# File name:  cat.11153.jpg
# File name:  cat.11154.jpg
# File name:  cat.11155.jpg
# File name:  cat.11156.jpg
# File name:  cat.11157.jpg
# File name:  cat.11158.jpg
# File name:  cat.11159.jpg
# File name:  cat.1116.jpg
# File name:  cat.11160.jpg
# File name:  cat.11161.jpg
# File name:  cat.11162.jpg
# File name:  cat.11163.jpg
# File name:  cat.11164.jpg
# File name:  cat.11165.jpg
# File name:  cat.11166.jpg
# File name:  cat.11167.jpg
# File name:  cat.11168.jpg
# File name:  cat.11169.jpg
# File name:  cat.1117.jpg
# File name:  cat.11170.jpg
# File name:  cat.11171.jpg
# File name:  cat.11172.jpg
# File name:  cat.11173.jpg
# File name:  cat.11174.jpg
# File name:  cat.11175.jpg
# File name:  cat.11176.jpg
# File name:  cat.11177.jpg
# File name:  cat.11178.jpg
# File name:  cat.11179.jpg
# File name:  cat.1118.jpg
# File name:  cat.11180.jpg
# File name:  cat.11181.jpg
# File name:  cat.11182.jpg
# File name:  cat.11183.jpg
# File name:  cat.11184.jpg
# File name:  cat.11185.jpg
# File name:  cat.11186.jpg
# File name:  cat.11187.jpg
# File name:  cat.11188.jpg
# File name:  cat.11189.jpg
# File name:  cat.1119.jpg
# File name:  cat.11190.jpg
# File name:  cat.11191.jpg
# File name:  cat.11192.jpg
# File name:  cat.11193.jpg
# File name:  cat.11194.jpg
# File name:  cat.11195.jpg
# File name:  cat.11196.jpg
# File name:  cat.11197.jpg
# File name:  cat.11198.jpg
# File name:  cat.11199.jpg
# File name:  cat.112.jpg
# File name:  cat.1120.jpg
# File name:  cat.11200.jpg
# File name:  cat.11201.jpg
# File name:  cat.11202.jpg
# File name:  cat.11203.jpg
# File name:  cat.11204.jpg
# File name:  cat.11205.jpg
# File name:  cat.11206.jpg
# File name:  cat.11207.jpg
# File name:  cat.11208.jpg
# File name:  cat.11209.jpg
# File name:  cat.1121.jpg
# File name:  cat.11210.jpg
# File name:  cat.11211.jpg
# File name:  cat.11212.jpg
# File name:  cat.11213.jpg
# File name:  cat.11214.jpg
# File name:  cat.11215.jpg
# File name:  cat.11216.jpg
# File name:  cat.11217.jpg
# File name:  cat.11218.jpg
# File name:  cat.11219.jpg
# File name:  cat.1122.jpg
# File name:  cat.11220.jpg
# File name:  cat.11221.jpg
# File name:  cat.11222.jpg
# File name:  cat.11223.jpg
# File name:  cat.11224.jpg
# File name:  cat.11225.jpg
# File name:  cat.11226.jpg
# File name:  cat.11227.jpg
# File name:  cat.11228.jpg
# File name:  cat.11229.jpg
# File name:  cat.1123.jpg
# File name:  cat.11230.jpg
# File name:  cat.11231.jpg
# File name:  cat.11232.jpg
# File name:  cat.11233.jpg
# File name:  cat.11234.jpg
# File name:  cat.11235.jpg
# File name:  cat.11236.jpg
# File name:  cat.11237.jpg
# File name:  cat.11238.jpg
# File name:  cat.11239.jpg
# File name:  cat.1124.jpg
# File name:  cat.11240.jpg
# File name:  cat.11241.jpg
# File name:  cat.11242.jpg
# File name:  cat.11243.jpg
# File name:  cat.11244.jpg
# File name:  cat.11245.jpg
# File name:  cat.11246.jpg
# File name:  cat.11247.jpg
# File name:  cat.11248.jpg
# File name:  cat.11249.jpg
# File name:  cat.1125.jpg
# File name:  cat.11250.jpg
# File name:  cat.11251.jpg
# File name:  cat.11252.jpg
# File name:  cat.11253.jpg
# File name:  cat.11254.jpg
# File name:  cat.11255.jpg
# File name:  cat.11256.jpg
# File name:  cat.11257.jpg
# File name:  cat.11258.jpg
# File name:  cat.11259.jpg
# File name:  cat.1126.jpg
# File name:  cat.11260.jpg
# File name:  cat.11261.jpg
# File name:  cat.11262.jpg
# File name:  cat.11263.jpg
# File name:  cat.11264.jpg
# File name:  cat.11265.jpg
# File name:  cat.11266.jpg
# File name:  cat.11267.jpg
# File name:  cat.11268.jpg
# File name:  cat.11269.jpg
# File name:  cat.1127.jpg
# File name:  cat.11270.jpg
# File name:  cat.11271.jpg
# File name:  cat.11272.jpg
# File name:  cat.11273.jpg
# File name:  cat.11274.jpg
# File name:  cat.11275.jpg
# File name:  cat.11276.jpg
# File name:  cat.11277.jpg
# File name:  cat.11278.jpg
# File name:  cat.11279.jpg
# File name:  cat.1128.jpg
# File name:  cat.11280.jpg
# File name:  cat.11281.jpg
# File name:  cat.11282.jpg
# File name:  cat.11283.jpg
# File name:  cat.11284.jpg
# File name:  cat.11285.jpg
# File name:  cat.11286.jpg
# File name:  cat.11287.jpg
# File name:  cat.11288.jpg
# File name:  cat.11289.jpg
# File name:  cat.1129.jpg
# File name:  cat.11290.jpg
# File name:  cat.11291.jpg
# File name:  cat.11292.jpg
# File name:  cat.11293.jpg
# File name:  cat.11294.jpg
# File name:  cat.11295.jpg
# File name:  cat.11296.jpg
# File name:  cat.11297.jpg
# File name:  cat.11298.jpg
# File name:  cat.11299.jpg
# File name:  cat.113.jpg
# File name:  cat.1130.jpg
# File name:  cat.11300.jpg
# File name:  cat.11301.jpg
# File name:  cat.11302.jpg
# File name:  cat.11303.jpg
# File name:  cat.11304.jpg
# File name:  cat.11305.jpg
# File name:  cat.11306.jpg
# File name:  cat.11307.jpg
# File name:  cat.11308.jpg
# File name:  cat.11309.jpg
# File name:  cat.1131.jpg
# File name:  cat.11310.jpg
# File name:  cat.11311.jpg
# File name:  cat.11312.jpg
# File name:  cat.11313.jpg
# File name:  cat.11314.jpg
# File name:  cat.11315.jpg
# File name:  cat.11316.jpg
# File name:  cat.11317.jpg
# File name:  cat.11318.jpg
# File name:  cat.11319.jpg
# File name:  cat.1132.jpg
# File name:  cat.11320.jpg
# File name:  cat.11321.jpg
# File name:  cat.11322.jpg
# File name:  cat.11323.jpg
# File name:  cat.11324.jpg
# File name:  cat.11325.jpg
# File name:  cat.11326.jpg
# File name:  cat.11327.jpg
# File name:  cat.11328.jpg
# File name:  cat.11329.jpg
# File name:  cat.1133.jpg
# File name:  cat.11330.jpg
# File name:  cat.11331.jpg
# File name:  cat.11332.jpg
# File name:  cat.11333.jpg
# File name:  cat.11334.jpg
# File name:  cat.11335.jpg
# File name:  cat.11336.jpg
# File name:  cat.11337.jpg
# File name:  cat.11338.jpg
# File name:  cat.11339.jpg
# File name:  cat.1134.jpg
# File name:  cat.11340.jpg
# File name:  cat.11341.jpg
# File name:  cat.11342.jpg
# File name:  cat.11343.jpg
# File name:  cat.11344.jpg
# File name:  cat.11345.jpg
# File name:  cat.11346.jpg
# File name:  cat.11347.jpg
# File name:  cat.11348.jpg
# File name:  cat.11349.jpg
# File name:  cat.1135.jpg
# File name:  cat.11350.jpg
# File name:  cat.11351.jpg
# File name:  cat.11352.jpg
# File name:  cat.11353.jpg
# File name:  cat.11354.jpg
# File name:  cat.11355.jpg
# File name:  cat.11356.jpg
# File name:  cat.11357.jpg
# File name:  cat.11358.jpg
# File name:  cat.11359.jpg
# File name:  cat.1136.jpg
# File name:  cat.11360.jpg
# File name:  cat.11361.jpg
# File name:  cat.11362.jpg
# File name:  cat.11363.jpg
# File name:  cat.11364.jpg
# File name:  cat.11365.jpg
# File name:  cat.11366.jpg
# File name:  cat.11367.jpg
# File name:  cat.11368.jpg
# File name:  cat.11369.jpg
# File name:  cat.1137.jpg
# File name:  cat.11370.jpg
# File name:  cat.11371.jpg
# File name:  cat.11372.jpg
# File name:  cat.11373.jpg
# File name:  cat.11374.jpg
# File name:  cat.11375.jpg
# File name:  cat.11376.jpg
# File name:  cat.11377.jpg
# File name:  cat.11378.jpg
# File name:  cat.11379.jpg
# File name:  cat.1138.jpg
# File name:  cat.11380.jpg
# File name:  cat.11381.jpg
# File name:  cat.11382.jpg
# File name:  cat.11383.jpg
# File name:  cat.11384.jpg
# File name:  cat.11385.jpg
# File name:  cat.11386.jpg
# File name:  cat.11387.jpg
# File name:  cat.11388.jpg
# File name:  cat.11389.jpg
# File name:  cat.1139.jpg
# File name:  cat.11390.jpg
# File name:  cat.11391.jpg
# File name:  cat.11392.jpg
# File name:  cat.11393.jpg
# File name:  cat.11394.jpg
# File name:  cat.11395.jpg
# File name:  cat.11396.jpg
# File name:  cat.11397.jpg
# File name:  cat.11398.jpg
# File name:  cat.11399.jpg
# File name:  cat.114.jpg
# File name:  cat.1140.jpg
# File name:  cat.11400.jpg
# File name:  cat.11401.jpg
# File name:  cat.11402.jpg
# File name:  cat.11403.jpg
# File name:  cat.11404.jpg
# File name:  cat.11405.jpg
# File name:  cat.11406.jpg
# File name:  cat.11407.jpg
# File name:  cat.11408.jpg
# File name:  cat.11409.jpg
# File name:  cat.1141.jpg
# File name:  cat.11410.jpg
# File name:  cat.11411.jpg
# File name:  cat.11412.jpg
# File name:  cat.11413.jpg
# File name:  cat.11414.jpg
# File name:  cat.11415.jpg
# File name:  cat.11416.jpg
# File name:  cat.11417.jpg
# File name:  cat.11418.jpg
# File name:  cat.11419.jpg
# File name:  cat.1142.jpg
# File name:  cat.11420.jpg
# File name:  cat.11421.jpg
# File name:  cat.11422.jpg
# File name:  cat.11423.jpg
# File name:  cat.11424.jpg
# File name:  cat.11425.jpg
# File name:  cat.11426.jpg
# File name:  cat.11427.jpg
# File name:  cat.11428.jpg
# File name:  cat.11429.jpg
# File name:  cat.1143.jpg
# File name:  cat.11430.jpg
# File name:  cat.11431.jpg
# File name:  cat.11432.jpg
# File name:  cat.11433.jpg
# File name:  cat.11434.jpg
# File name:  cat.11435.jpg
# File name:  cat.11436.jpg
# File name:  cat.11437.jpg
# File name:  cat.11438.jpg
# File name:  cat.11439.jpg
# File name:  cat.1144.jpg
# File name:  cat.11440.jpg
# File name:  cat.11441.jpg
# File name:  cat.11442.jpg
# File name:  cat.11443.jpg
# File name:  cat.11444.jpg
# File name:  cat.11445.jpg
# File name:  cat.11446.jpg
# File name:  cat.11447.jpg
# File name:  cat.11448.jpg
# File name:  cat.11449.jpg
# File name:  cat.1145.jpg
# File name:  cat.11450.jpg
# File name:  cat.11451.jpg
# File name:  cat.11452.jpg
# File name:  cat.11453.jpg
# File name:  cat.11454.jpg
# File name:  cat.11455.jpg
# File name:  cat.11456.jpg
# File name:  cat.11457.jpg
# File name:  cat.11458.jpg
# File name:  cat.11459.jpg
# File name:  cat.1146.jpg
# File name:  cat.11460.jpg
# File name:  cat.11461.jpg
# File name:  cat.11462.jpg
# File name:  cat.11463.jpg
# File name:  cat.11464.jpg
# File name:  cat.11465.jpg
# File name:  cat.11466.jpg
# File name:  cat.11467.jpg
# File name:  cat.11468.jpg
# File name:  cat.11469.jpg
# File name:  cat.1147.jpg
# File name:  cat.11470.jpg
# File name:  cat.11471.jpg
# File name:  cat.11472.jpg
# File name:  cat.11473.jpg
# File name:  cat.11474.jpg
# File name:  cat.11475.jpg
# File name:  cat.11476.jpg
# File name:  cat.11477.jpg
# File name:  cat.11478.jpg
# File name:  cat.11479.jpg
# File name:  cat.1148.jpg
# File name:  cat.11480.jpg
# File name:  cat.11481.jpg
# File name:  cat.11482.jpg
# File name:  cat.11483.jpg
# File name:  cat.11484.jpg
# File name:  cat.11485.jpg
# File name:  cat.11486.jpg
# File name:  cat.11487.jpg
# File name:  cat.11488.jpg
# File name:  cat.11489.jpg
# File name:  cat.1149.jpg
# File name:  cat.11490.jpg
# File name:  cat.11491.jpg
# File name:  cat.11492.jpg
# File name:  cat.11493.jpg
# File name:  cat.11494.jpg
# File name:  cat.11495.jpg
# File name:  cat.11496.jpg
# File name:  cat.11497.jpg
# File name:  cat.11498.jpg
# File name:  cat.11499.jpg
# File name:  cat.115.jpg
# File name:  cat.1150.jpg
# File name:  cat.11500.jpg
# File name:  cat.11501.jpg
# File name:  cat.11502.jpg
# File name:  cat.11503.jpg
# File name:  cat.11504.jpg
# File name:  cat.11505.jpg
# File name:  cat.11506.jpg
# File name:  cat.11507.jpg
# File name:  cat.11508.jpg
# File name:  cat.11509.jpg
# File name:  cat.1151.jpg
# File name:  cat.11510.jpg
# File name:  cat.11511.jpg
# File name:  cat.11512.jpg
# File name:  cat.11513.jpg
# File name:  cat.11514.jpg
# File name:  cat.11515.jpg
# File name:  cat.11516.jpg
# File name:  cat.11517.jpg
# File name:  cat.11518.jpg
# File name:  cat.11519.jpg
# File name:  cat.1152.jpg
# File name:  cat.11520.jpg
# File name:  cat.11521.jpg
# File name:  cat.11522.jpg
# File name:  cat.11523.jpg
# File name:  cat.11524.jpg
# File name:  cat.11525.jpg
# File name:  cat.11526.jpg
# File name:  cat.11527.jpg
# File name:  cat.11528.jpg
# File name:  cat.11529.jpg
# File name:  cat.1153.jpg
# File name:  cat.11530.jpg
# File name:  cat.11531.jpg
# File name:  cat.11532.jpg
# File name:  cat.11533.jpg
# File name:  cat.11534.jpg
# File name:  cat.11535.jpg
# File name:  cat.11536.jpg
# File name:  cat.11537.jpg
# File name:  cat.11538.jpg
# File name:  cat.11539.jpg
# File name:  cat.1154.jpg
# File name:  cat.11540.jpg
# File name:  cat.11541.jpg
# File name:  cat.11542.jpg
# File name:  cat.11543.jpg
# File name:  cat.11544.jpg
# File name:  cat.11545.jpg
# File name:  cat.11546.jpg
# File name:  cat.11547.jpg
# File name:  cat.11548.jpg
# File name:  cat.11549.jpg
# File name:  cat.1155.jpg
# File name:  cat.11550.jpg
# File name:  cat.11551.jpg
# File name:  cat.11552.jpg
# File name:  cat.11553.jpg
# File name:  cat.11554.jpg
# File name:  cat.11555.jpg
# File name:  cat.11556.jpg
# File name:  cat.11557.jpg
# File name:  cat.11558.jpg
# File name:  cat.11559.jpg
# File name:  cat.1156.jpg
# File name:  cat.11560.jpg
# File name:  cat.11561.jpg
# File name:  cat.11562.jpg
# File name:  cat.11563.jpg
# File name:  cat.11564.jpg
# File name:  cat.11565.jpg
# File name:  cat.11566.jpg
# File name:  cat.11567.jpg
# File name:  cat.11568.jpg
# File name:  cat.11569.jpg
# File name:  cat.1157.jpg
# File name:  cat.11570.jpg
# File name:  cat.11571.jpg
# File name:  cat.11572.jpg
# File name:  cat.11573.jpg
# File name:  cat.11574.jpg
# File name:  cat.11575.jpg
# File name:  cat.11576.jpg
# File name:  cat.11577.jpg
# File name:  cat.11578.jpg
# File name:  cat.11579.jpg
# File name:  cat.1158.jpg
# File name:  cat.11580.jpg
# File name:  cat.11581.jpg
# File name:  cat.11582.jpg
# File name:  cat.11583.jpg
# File name:  cat.11584.jpg
# File name:  cat.11585.jpg
# File name:  cat.11586.jpg
# File name:  cat.11587.jpg
# File name:  cat.11588.jpg
# File name:  cat.11589.jpg
# File name:  cat.1159.jpg
# File name:  cat.11590.jpg
# File name:  cat.11591.jpg
# File name:  cat.11592.jpg
# File name:  cat.11593.jpg
# File name:  cat.11594.jpg
# File name:  cat.11595.jpg
# File name:  cat.11596.jpg
# File name:  cat.11597.jpg
# File name:  cat.11598.jpg
# File name:  cat.11599.jpg
# File name:  cat.116.jpg
# File name:  cat.1160.jpg
# File name:  cat.11600.jpg
# File name:  cat.11601.jpg
# File name:  cat.11602.jpg
# File name:  cat.11603.jpg
# File name:  cat.11604.jpg
# File name:  cat.11605.jpg
# File name:  cat.11606.jpg
# File name:  cat.11607.jpg
# File name:  cat.11608.jpg
# File name:  cat.11609.jpg
# File name:  cat.1161.jpg
# File name:  cat.11610.jpg
# File name:  cat.11611.jpg
# File name:  cat.11612.jpg
# File name:  cat.11613.jpg
# File name:  cat.11614.jpg
# File name:  cat.11615.jpg
# File name:  cat.11616.jpg
# File name:  cat.11617.jpg
# File name:  cat.11618.jpg
# File name:  cat.11619.jpg
# File name:  cat.1162.jpg
# File name:  cat.11620.jpg
# File name:  cat.11621.jpg
# File name:  cat.11622.jpg
# File name:  cat.11623.jpg
# File name:  cat.11624.jpg
# File name:  cat.11625.jpg
# File name:  cat.11626.jpg
# File name:  cat.11627.jpg
# File name:  cat.11628.jpg
# File name:  cat.11629.jpg
# File name:  cat.1163.jpg
# File name:  cat.11630.jpg
# File name:  cat.11631.jpg
# File name:  cat.11632.jpg
# File name:  cat.11633.jpg
# File name:  cat.11634.jpg
# File name:  cat.11635.jpg
# File name:  cat.11636.jpg
# File name:  cat.11637.jpg
# File name:  cat.11638.jpg
# File name:  cat.11639.jpg
# File name:  cat.1164.jpg
# File name:  cat.11640.jpg
# File name:  cat.11641.jpg
# File name:  cat.11642.jpg
# File name:  cat.11643.jpg
# File name:  cat.11644.jpg
# File name:  cat.11645.jpg
# File name:  cat.11646.jpg
# File name:  cat.11647.jpg
# File name:  cat.11648.jpg
# File name:  cat.11649.jpg
# File name:  cat.1165.jpg
# File name:  cat.11650.jpg
# File name:  cat.11651.jpg
# File name:  cat.11652.jpg
# File name:  cat.11653.jpg
# File name:  cat.11654.jpg
# File name:  cat.11655.jpg
# File name:  cat.11656.jpg
# File name:  cat.11657.jpg
# File name:  cat.11658.jpg
# File name:  cat.11659.jpg
# File name:  cat.1166.jpg
# ...
# File name:  cat.949.jpg
# File name:  cat.9490.jpg
# File name:  cat.9491.jpg
# File name:  cat.9492.jpg
# File name:  cat.9493.jpg
# File name:  cat.9494.jpg
# File name:  cat.9495.jpg
# File name:  cat.9496.jpg
# File name:  cat.9497.jpg
# File name:  cat.9498.jpg
# File name:  cat.9499.jpg
# File name:  cat.95.jpg
# File name:  cat.950.jpg
# File name:  cat.9500.jpg
# File name:  cat.9501.jpg
# File name:  cat.9502.jpg
# File name:  cat.9503.jpg
# File name:  cat.9504.jpg
# File name:  cat.9505.jpg
# File name:  cat.9506.jpg
# File name:  cat.9507.jpg
# File name:  cat.9508.jpg
# File name:  cat.9509.jpg
# File name:  cat.951.jpg
# File name:  cat.9510.jpg
# File name:  cat.9511.jpg
# File name:  cat.9512.jpg
# File name:  cat.9513.jpg
# File name:  cat.9514.jpg
# File name:  cat.9515.jpg
# File name:  cat.9516.jpg
# File name:  cat.9517.jpg
# File name:  cat.9518.jpg
# File name:  cat.9519.jpg
# File name:  cat.952.jpg
# File name:  cat.9520.jpg
# File name:  cat.9521.jpg
# File name:  cat.9522.jpg
# File name:  cat.9523.jpg
# File name:  cat.9524.jpg
# File name:  cat.9525.jpg
# File name:  cat.9526.jpg
# File name:  cat.9527.jpg
# File name:  cat.9528.jpg
# File name:  cat.9529.jpg
# File name:  cat.953.jpg
# File name:  cat.9530.jpg
# File name:  cat.9531.jpg
# File name:  cat.9532.jpg
# File name:  cat.9533.jpg
# File name:  cat.9534.jpg
# File name:  cat.9535.jpg
# File name:  cat.9536.jpg
# File name:  cat.9537.jpg
# File name:  cat.9538.jpg
# File name:  cat.9539.jpg
# File name:  cat.954.jpg
# File name:  cat.9540.jpg
# File name:  cat.9541.jpg
# File name:  cat.9542.jpg
# File name:  cat.9543.jpg
# File name:  cat.9544.jpg
# File name:  cat.9545.jpg
# File name:  cat.9546.jpg
# File name:  cat.9547.jpg
# File name:  cat.9548.jpg
# File name:  cat.9549.jpg
# File name:  cat.955.jpg
# File name:  cat.9550.jpg
# File name:  cat.9551.jpg
# File name:  cat.9552.jpg
# File name:  cat.9553.jpg
# File name:  cat.9554.jpg
# File name:  cat.9555.jpg
# File name:  cat.9556.jpg
# File name:  cat.9557.jpg
# File name:  cat.9558.jpg
# File name:  cat.9559.jpg
# File name:  cat.956.jpg
# File name:  cat.9560.jpg
# File name:  cat.9561.jpg
# File name:  cat.9562.jpg
# File name:  cat.9563.jpg
# File name:  cat.9564.jpg
# File name:  cat.9565.jpg
# File name:  cat.9566.jpg
# File name:  cat.9567.jpg
# File name:  cat.9568.jpg
# File name:  cat.9569.jpg
# File name:  cat.957.jpg
# File name:  cat.9570.jpg
# File name:  cat.9571.jpg
# File name:  cat.9572.jpg
# File name:  cat.9573.jpg
# File name:  cat.9574.jpg
# File name:  cat.9575.jpg
# File name:  cat.9576.jpg
# File name:  cat.9577.jpg
# File name:  cat.9578.jpg
# File name:  cat.9579.jpg
# File name:  cat.958.jpg
# File name:  cat.9580.jpg
# File name:  cat.9581.jpg
# File name:  cat.9582.jpg
# File name:  cat.9583.jpg
# File name:  cat.9584.jpg
# File name:  cat.9585.jpg
# File name:  cat.9586.jpg
# File name:  cat.9587.jpg
# File name:  cat.9588.jpg
# File name:  cat.9589.jpg
# File name:  cat.959.jpg
# File name:  cat.9590.jpg
# File name:  cat.9591.jpg
# File name:  cat.9592.jpg
# File name:  cat.9593.jpg
# File name:  cat.9594.jpg
# File name:  cat.9595.jpg
# File name:  cat.9596.jpg
# File name:  cat.9597.jpg
# File name:  cat.9598.jpg
# File name:  cat.9599.jpg
# File name:  cat.96.jpg
# File name:  cat.960.jpg
# File name:  cat.9600.jpg
# File name:  cat.9601.jpg
# File name:  cat.9602.jpg
# File name:  cat.9603.jpg
# File name:  cat.9604.jpg
# File name:  cat.9605.jpg
# File name:  cat.9606.jpg
# File name:  cat.9607.jpg
# File name:  cat.9608.jpg
# File name:  cat.9609.jpg
# File name:  cat.961.jpg
# File name:  cat.9610.jpg
# File name:  cat.9611.jpg
# File name:  cat.9612.jpg
# File name:  cat.9613.jpg
# File name:  cat.9614.jpg
# File name:  cat.9615.jpg
# File name:  cat.9616.jpg
# File name:  cat.9617.jpg
# File name:  cat.9618.jpg
# File name:  cat.9619.jpg
# File name:  cat.962.jpg
# File name:  cat.9620.jpg
# File name:  cat.9621.jpg
# File name:  cat.9622.jpg
# File name:  cat.9623.jpg
# File name:  cat.9624.jpg
# File name:  cat.9625.jpg
# File name:  cat.9626.jpg
# File name:  cat.9627.jpg
# File name:  cat.9628.jpg
# File name:  cat.9629.jpg
# File name:  cat.963.jpg
# File name:  cat.9630.jpg
# File name:  cat.9631.jpg
# File name:  cat.9632.jpg
# File name:  cat.9633.jpg
# File name:  cat.9634.jpg
# File name:  cat.9635.jpg
# File name:  cat.9636.jpg
# File name:  cat.9637.jpg
# File name:  cat.9638.jpg
# File name:  cat.9639.jpg
# File name:  cat.964.jpg
# File name:  cat.9640.jpg
# File name:  cat.9641.jpg
# File name:  cat.9642.jpg
# File name:  cat.9643.jpg
# File name:  cat.9644.jpg
# File name:  cat.9645.jpg
# File name:  cat.9646.jpg
# File name:  cat.9647.jpg
# File name:  cat.9648.jpg
# File name:  cat.9649.jpg
# File name:  cat.965.jpg
# File name:  cat.9650.jpg
# File name:  cat.9651.jpg
# File name:  cat.9652.jpg
# File name:  cat.9653.jpg
# File name:  cat.9654.jpg
# File name:  cat.9655.jpg
# File name:  cat.9656.jpg
# File name:  cat.9657.jpg
# File name:  cat.9658.jpg
# File name:  cat.9659.jpg
# File name:  cat.966.jpg
# File name:  cat.9660.jpg
# File name:  cat.9661.jpg
# File name:  cat.9662.jpg
# File name:  cat.9663.jpg
# File name:  cat.9664.jpg
# File name:  cat.9665.jpg
# File name:  cat.9666.jpg
# File name:  cat.9667.jpg
# File name:  cat.9668.jpg
# File name:  cat.9669.jpg
# File name:  cat.967.jpg
# File name:  cat.9670.jpg
# File name:  cat.9671.jpg
# File name:  cat.9672.jpg
# File name:  cat.9673.jpg
# File name:  cat.9674.jpg
# File name:  cat.9675.jpg
# File name:  cat.9676.jpg
# File name:  cat.9677.jpg
# File name:  cat.9678.jpg
# File name:  cat.9679.jpg
# File name:  cat.968.jpg
# File name:  cat.9680.jpg
# File name:  cat.9681.jpg
# File name:  cat.9682.jpg
# File name:  cat.9683.jpg
# File name:  cat.9684.jpg
# File name:  cat.9685.jpg
# File name:  cat.9686.jpg
# File name:  cat.9687.jpg
# File name:  cat.9688.jpg
# File name:  cat.9689.jpg
# File name:  cat.969.jpg
# File name:  cat.9690.jpg
# File name:  cat.9691.jpg
# File name:  cat.9692.jpg
# File name:  cat.9693.jpg
# File name:  cat.9694.jpg
# File name:  cat.9695.jpg
# File name:  cat.9696.jpg
# File name:  cat.9697.jpg
# File name:  cat.9698.jpg
# File name:  cat.9699.jpg
# File name:  cat.97.jpg
# File name:  cat.970.jpg
# File name:  cat.9700.jpg
# File name:  cat.9701.jpg
# File name:  cat.9702.jpg
# File name:  cat.9703.jpg
# File name:  cat.9704.jpg
# File name:  cat.9705.jpg
# File name:  cat.9706.jpg
# File name:  cat.9707.jpg
# File name:  cat.9708.jpg
# File name:  cat.9709.jpg
# File name:  cat.971.jpg
# File name:  cat.9710.jpg
# File name:  cat.9711.jpg
# File name:  cat.9712.jpg
# File name:  cat.9713.jpg
# File name:  cat.9714.jpg
# File name:  cat.9715.jpg
# File name:  cat.9716.jpg
# File name:  cat.9717.jpg
# File name:  cat.9718.jpg
# File name:  cat.9719.jpg
# File name:  cat.972.jpg
# File name:  cat.9720.jpg
# File name:  cat.9721.jpg
# File name:  cat.9722.jpg
# File name:  cat.9723.jpg
# File name:  cat.9724.jpg
# File name:  cat.9725.jpg
# File name:  cat.9726.jpg
# File name:  cat.9727.jpg
# File name:  cat.9728.jpg
# File name:  cat.9729.jpg
# File name:  cat.973.jpg
# File name:  cat.9730.jpg
# File name:  cat.9731.jpg
# File name:  cat.9732.jpg
# File name:  cat.9733.jpg
# File name:  cat.9734.jpg
# File name:  cat.9735.jpg
# File name:  cat.9736.jpg
# File name:  cat.9737.jpg
# File name:  cat.9738.jpg
# File name:  cat.9739.jpg
# File name:  cat.974.jpg
# File name:  cat.9740.jpg
# File name:  cat.9741.jpg
# File name:  cat.9742.jpg
# File name:  cat.9743.jpg
# File name:  cat.9744.jpg
# File name:  cat.9745.jpg
# File name:  cat.9746.jpg
# File name:  cat.9747.jpg
# File name:  cat.9748.jpg
# File name:  cat.9749.jpg
# File name:  cat.975.jpg
# File name:  cat.9750.jpg
# File name:  cat.9751.jpg
# File name:  cat.9752.jpg
# File name:  cat.9753.jpg
# File name:  cat.9754.jpg
# File name:  cat.9755.jpg
# File name:  cat.9756.jpg
# File name:  cat.9757.jpg
# File name:  cat.9758.jpg
# File name:  cat.9759.jpg
# File name:  cat.976.jpg
# File name:  cat.9760.jpg
# File name:  cat.9761.jpg
# File name:  cat.9762.jpg
# File name:  cat.9763.jpg
# File name:  cat.9764.jpg
# File name:  cat.9765.jpg
# File name:  cat.9766.jpg
# File name:  cat.9767.jpg
# File name:  cat.9768.jpg
# File name:  cat.9769.jpg
# File name:  cat.977.jpg
# File name:  cat.9770.jpg
# File name:  cat.9771.jpg
# File name:  cat.9772.jpg
# File name:  cat.9773.jpg
# File name:  cat.9774.jpg
# File name:  cat.9775.jpg
# File name:  cat.9776.jpg
# File name:  cat.9777.jpg
# File name:  cat.9778.jpg
# File name:  cat.9779.jpg
# File name:  cat.978.jpg
# File name:  cat.9780.jpg
# File name:  cat.9781.jpg
# File name:  cat.9782.jpg
# File name:  cat.9783.jpg
# File name:  cat.9784.jpg
# File name:  cat.9785.jpg
# File name:  cat.9786.jpg
# File name:  cat.9787.jpg
# File name:  cat.9788.jpg
# File name:  cat.9789.jpg
# File name:  cat.979.jpg
# File name:  cat.9790.jpg
# File name:  cat.9791.jpg
# File name:  cat.9792.jpg
# File name:  cat.9793.jpg
# File name:  cat.9794.jpg
# File name:  cat.9795.jpg
# File name:  cat.9796.jpg
# File name:  cat.9797.jpg
# File name:  cat.9798.jpg
# File name:  cat.9799.jpg
# File name:  cat.98.jpg
# File name:  cat.980.jpg
# File name:  cat.9800.jpg
# File name:  cat.9801.jpg
# File name:  cat.9802.jpg
# File name:  cat.9803.jpg
# File name:  cat.9804.jpg
# File name:  cat.9805.jpg
# File name:  cat.9806.jpg
# File name:  cat.9807.jpg
# File name:  cat.9808.jpg
# File name:  cat.9809.jpg
# File name:  cat.981.jpg
# File name:  cat.9810.jpg
# File name:  cat.9811.jpg
# File name:  cat.9812.jpg
# File name:  cat.9813.jpg
# File name:  cat.9814.jpg
# File name:  cat.9815.jpg
# File name:  cat.9816.jpg
# File name:  cat.9817.jpg
# File name:  cat.9818.jpg
# File name:  cat.9819.jpg
# File name:  cat.982.jpg
# File name:  cat.9820.jpg
# File name:  cat.9821.jpg
# File name:  cat.9822.jpg
# File name:  cat.9823.jpg
# File name:  cat.9824.jpg
# File name:  cat.9825.jpg
# File name:  cat.9826.jpg
# File name:  cat.9827.jpg
# File name:  cat.9828.jpg
# File name:  cat.9829.jpg
# File name:  cat.983.jpg
# File name:  cat.9830.jpg
# File name:  cat.9831.jpg
# File name:  cat.9832.jpg
# File name:  cat.9833.jpg
# File name:  cat.9834.jpg
# File name:  cat.9835.jpg
# File name:  cat.9836.jpg
# File name:  cat.9837.jpg
# File name:  cat.9838.jpg
# File name:  cat.9839.jpg
# File name:  cat.984.jpg
# File name:  cat.9840.jpg
# File name:  cat.9841.jpg
# File name:  cat.9842.jpg
# File name:  cat.9843.jpg
# File name:  cat.9844.jpg
# File name:  cat.9845.jpg
# File name:  cat.9846.jpg
# File name:  cat.9847.jpg
# File name:  cat.9848.jpg
# File name:  cat.9849.jpg
# File name:  cat.985.jpg
# File name:  cat.9850.jpg
# File name:  cat.9851.jpg
# File name:  cat.9852.jpg
# File name:  cat.9853.jpg
# File name:  cat.9854.jpg
# File name:  cat.9855.jpg
# File name:  cat.9856.jpg
# File name:  cat.9857.jpg
# File name:  cat.9858.jpg
# File name:  cat.9859.jpg
# File name:  cat.986.jpg
# File name:  cat.9860.jpg
# File name:  cat.9861.jpg
# File name:  cat.9862.jpg
# File name:  cat.9863.jpg
# File name:  cat.9864.jpg
# File name:  cat.9865.jpg
# File name:  cat.9866.jpg
# File name:  cat.9867.jpg
# File name:  cat.9868.jpg
# File name:  cat.9869.jpg
# File name:  cat.987.jpg
# File name:  cat.9870.jpg
# File name:  cat.9871.jpg
# File name:  cat.9872.jpg
# File name:  cat.9873.jpg
# File name:  cat.9874.jpg
# File name:  cat.9875.jpg
# File name:  cat.9876.jpg
# File name:  cat.9877.jpg
# File name:  cat.9878.jpg
# File name:  cat.9879.jpg
# File name:  cat.988.jpg
# File name:  cat.9880.jpg
# File name:  cat.9881.jpg
# File name:  cat.9882.jpg
# File name:  cat.9883.jpg
# File name:  cat.9884.jpg
# File name:  cat.9885.jpg
# File name:  cat.9886.jpg
# File name:  cat.9887.jpg
# File name:  cat.9888.jpg
# File name:  cat.9889.jpg
# File name:  cat.989.jpg
# File name:  cat.9890.jpg
# File name:  cat.9891.jpg
# File name:  cat.9892.jpg
# File name:  cat.9893.jpg
# File name:  cat.9894.jpg
# File name:  cat.9895.jpg
# File name:  cat.9896.jpg
# File name:  cat.9897.jpg
# File name:  cat.9898.jpg
# File name:  cat.9899.jpg
# File name:  cat.99.jpg
# File name:  cat.990.jpg
# File name:  cat.9900.jpg
# File name:  cat.9901.jpg
# File name:  cat.9902.jpg
# File name:  cat.9903.jpg
# File name:  cat.9904.jpg
# File name:  cat.9905.jpg
# File name:  cat.9906.jpg
# File name:  cat.9907.jpg
# File name:  cat.9908.jpg
# File name:  cat.9909.jpg
# File name:  cat.991.jpg
# File name:  cat.9910.jpg
# File name:  cat.9911.jpg
# File name:  cat.9912.jpg
# File name:  cat.9913.jpg
# File name:  cat.9914.jpg
# File name:  cat.9915.jpg
# File name:  cat.9916.jpg
# File name:  cat.9917.jpg
# File name:  cat.9918.jpg
# File name:  cat.9919.jpg
# File name:  cat.992.jpg
# File name:  cat.9920.jpg
# File name:  cat.9921.jpg
# File name:  cat.9922.jpg
# File name:  cat.9923.jpg
# File name:  cat.9924.jpg
# File name:  cat.9925.jpg
# File name:  cat.9926.jpg
# File name:  cat.9927.jpg
# File name:  cat.9928.jpg
# File name:  cat.9929.jpg
# File name:  cat.993.jpg
# File name:  cat.9930.jpg
# File name:  cat.9931.jpg
# File name:  cat.9932.jpg
# File name:  cat.9933.jpg
# File name:  cat.9934.jpg
# File name:  cat.9935.jpg
# File name:  cat.9936.jpg
# File name:  cat.9937.jpg
# File name:  cat.9938.jpg
# File name:  cat.9939.jpg
# File name:  cat.994.jpg
# File name:  cat.9940.jpg
# File name:  cat.9941.jpg
# File name:  cat.9942.jpg
# File name:  cat.9943.jpg
# File name:  cat.9944.jpg
# File name:  cat.9945.jpg
# File name:  cat.9946.jpg
# File name:  cat.9947.jpg
# File name:  cat.9948.jpg
# File name:  cat.9949.jpg
# File name:  cat.995.jpg
# File name:  cat.9950.jpg
# File name:  cat.9951.jpg
# File name:  cat.9952.jpg
# File name:  cat.9953.jpg
# File name:  cat.9954.jpg
# File name:  cat.9955.jpg
# File name:  cat.9956.jpg
# File name:  cat.9957.jpg
# File name:  cat.9958.jpg
# File name:  cat.9959.jpg
# File name:  cat.996.jpg
# File name:  cat.9960.jpg
# File name:  cat.9961.jpg
# File name:  cat.9962.jpg
# File name:  cat.9963.jpg
# File name:  cat.9964.jpg
# File name:  cat.9965.jpg
# File name:  cat.9966.jpg
# File name:  cat.9967.jpg
# File name:  cat.9968.jpg
# File name:  cat.9969.jpg
# File name:  cat.997.jpg
# File name:  cat.9970.jpg
# File name:  cat.9971.jpg
# File name:  cat.9972.jpg
# File name:  cat.9973.jpg
# File name:  cat.9974.jpg
# File name:  cat.9975.jpg
# File name:  cat.9976.jpg
# File name:  cat.9977.jpg
# File name:  cat.9978.jpg
# File name:  cat.9979.jpg
# File name:  cat.998.jpg
# File name:  cat.9980.jpg
# File name:  cat.9981.jpg
# File name:  cat.9982.jpg
# File name:  cat.9983.jpg
# File name:  cat.9984.jpg
# File name:  cat.9985.jpg
# File name:  cat.9986.jpg
# File name:  cat.9987.jpg
# File name:  cat.9988.jpg
# File name:  cat.9989.jpg
# File name:  cat.999.jpg
# File name:  cat.9990.jpg
# File name:  cat.9991.jpg
# File name:  cat.9992.jpg
# File name:  cat.9993.jpg
# File name:  cat.9994.jpg
# File name:  cat.9995.jpg
# File name:  cat.9996.jpg
# File name:  cat.9997.jpg
# File name:  cat.9998.jpg
# File name:  cat.9999.jpg
# Directory path:  data/cats_dogs_kaggle/train/cat
# Folder name:  []
# File name:  cat.0.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/tf-2.2/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     790     try:
# --> 791         os.rename(src, real_dst)
#     792     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cats_dogs_kaggle/train/cat/cat.0.jpg' -> 'data/cats_dogs_kaggle/train/cat/cat/cat.0.jpg'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-ca7703132ebf> in <module>
#      15             old_path = dirpath + '/' + filename
#      16             new_path = dirpath + '/cat/' + filename
# ---> 17             shutil.move(old_path, new_path)
#
# ~/anaconda3/envs/tf-2.2/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     803             rmtree(src)
#     804         else:
# --> 805             copy_function(src, real_dst)
#     806             os.unlink(src)
#     807     return real_dst
#
# ~/anaconda3/envs/tf-2.2/lib/python3.8/shutil.py in copy2(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copystat(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# ~/anaconda3/envs/tf-2.2/lib/python3.8/shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265             # macOS
#     266             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cats_dogs_kaggle/train/cat/cat/cat.0.jpg'

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms

# import helper  # helper function is defined below, no need for importing

# %% [markdown]
# >  Helper function is defined before. Click to show.

# %%
# define helper.py 
import matplotlib.pyplot as plt
import numpy as np
from torch import nn, optim
from torch.autograd import Variable


def test_network(net, trainloader):

    criterion = nn.MSELoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)

    dataiter = iter(trainloader)
    images, labels = dataiter.next()

    # Create Variables for the inputs and targets
    inputs = Variable(images)
    targets = Variable(images)

    # Clear the gradients from all Variables
    optimizer.zero_grad()

    # Forward pass, then backward pass, then update weights
    output = net.forward(inputs)
    loss = criterion(output, targets)
    loss.backward()
    optimizer.step()

    return True


def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax


def view_recon(img, recon):
    ''' Function for displaying an image (as a PyTorch Tensor) and its
        reconstruction also a PyTorch Tensor
    '''

    fig, axes = plt.subplots(ncols=2, sharex=True, sharey=True)
    axes[0].imshow(img.numpy().squeeze())
    axes[1].imshow(recon.data.numpy().squeeze())
    for ax in axes:
        ax.axis('off')
        ax.set_adjustable('box-forced')

def view_classify(img, ps, version="MNIST"):
    ''' Function for viewing an image and it's predicted classes.
    '''
    ps = ps.data.numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    if version == "MNIST":
        ax2.set_yticklabels(np.arange(10))
    elif version == "Fashion":
        ax2.set_yticklabels(['T-shirt/top',
                            'Trouser',
                            'Pullover',
                            'Dress',
                            'Coat',
                            'Sandal',
                            'Shirt',
                            'Sneaker',
                            'Bag',
                            'Ankle Boot'], size='small');
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

# %% [markdown]
# The easiest way to load image data is with `datasets.ImageFolder` from `torchvision` ([documentation](http://pytorch.org/docs/master/torchvision/datasets.html#imagefolder)). In general you'll use `ImageFolder` like so:
#
# ```python
# dataset = datasets.ImageFolder('path/to/data', transform=transform)
# ```
#
# where `'path/to/data'` is the file path to the data directory and `transform` is a list of processing steps built with the [`transforms`](http://pytorch.org/docs/master/torchvision/transforms.html) module from `torchvision`. ImageFolder expects the files and directories to be constructed like so:
# ```
# root/dog/xxx.png
# root/dog/xxy.png
# root/dog/xxz.png
#
# root/cat/123.png
# root/cat/nsdf3.png
# root/cat/asd932_.png
# ```
#
# where each class has it's own directory (`cat` and `dog`) for the images. The images are then labeled with the class taken from the directory name. So here, the image `123.png` would be loaded with the class label `cat`. You can download the dataset already structured like this [from here](https://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip). I've also split it into a training set and test set.
#
# ### Transforms
#
# When you load in the data with `ImageFolder`, you'll need to define some transforms. For example, the images are different sizes but we'll need them to all be the same size for training. You can either resize them with `transforms.Resize()` or crop with `transforms.CenterCrop()`, `transforms.RandomResizedCrop()`, etc. We'll also need to convert the images to PyTorch tensors with `transforms.ToTensor()`. Typically you'll combine these transforms into a pipeline with `transforms.Compose()`, which accepts a list of transforms and runs them in sequence. It looks something like this to scale, then crop, then convert to a tensor:
#
# ```python
# transform = transforms.Compose([transforms.Resize(255),
#                                  transforms.CenterCrop(224),
#                                  transforms.ToTensor()])
#
# ```
#
# There are plenty of transforms available, I'll cover more in a bit and you can read through the [documentation](http://pytorch.org/docs/master/torchvision/transforms.html).
#
# ### Data Loaders
#
# With the `ImageFolder` loaded, you have to pass it to a [`DataLoader`](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader). The `DataLoader` takes a dataset (such as you would get from `ImageFolder`) and returns batches of images and the corresponding labels. You can set various parameters like the batch size and if the data is shuffled after each epoch.
#
# ```python
# dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
# ```
#
# Here `dataloader` is a [generator](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/). To get data out of it, you need to loop through it or convert it to an iterator and call `next()`.
#
# ```python
# # Looping through it, get a batch on each loop
# for images, labels in dataloader:
#     pass
#
# # Get one batch
# images, labels = next(iter(dataloader))
# ```
#
# > ### **Exercise:** Load images from the `Cat_Dog_data/train` folder, define a few transforms, then build the dataloader.

# %%
# Define default PATH
PATH = '../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data'

# %%
# data_dir = 'Cat_Dog_data/train'
data_dir = PATH + '/train' # load from Kaggle

transform = transforms.Compose([transforms.Resize(255),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()
                               ])# TODO: compose transforms here
dataset = datasets.ImageFolder(data_dir, transform=transform) # TODO: create the ImageFolder
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True) # TODO: use the ImageFolder dataset to create the DataLoader

# %%
data_dir
# Out:
# '../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data/train'

# %%
# Run this to test your data loader
images, labels = next(iter(dataloader))
# helper.imshow(images[0], normalize=False)
imshow(images[0], normalize=False)

# %% [markdown]
# If you loaded the data correctly, you should see something like this (your image will be different):
#
# ![Image](https://github.com/udacity/deep-learning-v2-pytorch/raw/master/intro-to-pytorch/assets/cat_cropped.png)

# %% [markdown]
# ## Data Augmentation
#
# A common strategy for training neural networks is to introduce randomness in the input data itself. For example, you can randomly rotate, mirror, scale, and/or crop your images during training. This will help your network generalize as it's seeing the same images but in different locations, with different sizes, in different orientations, etc.
#
# To randomly rotate, scale and crop, then flip your images you would define your transforms like this:
#
# ```python
# train_transforms = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.5, 0.5, 0.5],
#                                                             [0.5, 0.5, 0.5])])
# ```
#
# You'll also typically want to normalize images with `transforms.Normalize`. You pass in a list of means and list of standard deviations, then the color channels are normalized like so
#
# ```input[channel] = (input[channel] - mean[channel]) / std[channel]```
#
# Subtracting `mean` centers the data around zero and dividing by `std` squishes the values to be between -1 and 1. Normalizing helps keep the network work weights near zero which in turn makes backpropagation more stable. Without normalization, networks will tend to fail to learn.
#
# You can find a list of all [the available transforms here](http://pytorch.org/docs/0.3.0/torchvision/transforms.html). When you're testing however, you'll want to use images that aren't altered (except you'll need to normalize the same way). So, for validation/test images, you'll typically just resize and crop.
#
# >### **Exercise:** Define transforms for training data and testing data below. Leave off normalization for now.

# %%
PATH
# Out:
# '../input/dogs-vs-cats-for-pytorch/cat_dog_data/Cat_Dog_data'

# %%
# data_dir = 'Cat_Dog_data'
data_dir = PATH

# TODO: Define transforms for the training data and testing data
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor()])

test_transforms = transforms.Compose([transforms.RandomRotation(30),
                                     transforms.RandomResizedCrop(224),
                                     transforms.ToTensor()])


# Pass transforms in here, then run the next cell to see how the transforms look
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=32)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# %%
# change this to the trainloader or testloader 
data_iter = iter(testloader)

images, labels = next(data_iter)
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
#     helper.imshow(images[ii], ax=ax, normalize=False)
    imshow(images[ii], ax=ax, normalize=False)

# %% [markdown]
# Your transformed images should look something like this.
#
#
# ![](https://github.com/udacity/deep-learning-v2-pytorch/raw/master/intro-to-pytorch/assets/train_examples.png)
#
#
# ![](https://github.com/udacity/deep-learning-v2-pytorch/raw/master/intro-to-pytorch/assets/test_examples.png)

# %% [markdown]
# At this point you should be able to load data for training and testing. Now, you should try building a network that can classify cats vs dogs. This is quite a bit more complicated than before with the MNIST and Fashion-MNIST datasets. To be honest, you probably won't get it to work with a fully-connected network, no matter how deep. These images have three color channels and at a higher resolution (so far you've seen 28x28 images which are tiny).
#
# In the next part, I'll show you how to use a pre-trained network to build a model that can actually solve this problem.

# %%
# Optional TODO: Attempt to build a network to classify cats vs dogs from this dataset

# %% [markdown]
# >  Great! Continue the next notebook of [Transfer Learning](https://www.kaggle.com/leifuer/intro-to-pytorch-transfer-learning)
